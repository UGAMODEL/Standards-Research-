# %%
from bertopic import BERTopic

from bertopic.representation import KeyBERTInspired
from bertopic.representation import PartOfSpeech
from bertopic.representation import MaximalMarginalRelevance
from sklearn.datasets import fetch_20newsgroups
import pandas as pd  # Import pandas after reinstalling it
from sklearn.model_selection import train_test_split

# %%
# Documents to train on
df = pd.read_csv("output.csv")
df = df.loc[(df.label == "standard") |(df.label == "requirement")  ]
print(df.groupby("label").count())
print(df.head())
requirements = df.text.tolist()
labels = df.label.map({'standard': 1, 'requirement': 0}).tolist()
# Out:
#              text  document
# label
# requirement  1303      1303
# standard      204       204
#                                                 text        label  \
# 0  CSP_Mid.CBF shall have a Maintenance Down Time...  requirement
# 1  When commanded, CSP_Mid.CBF shall perform auto...  requirement
# 2   Each box end end blast station paddle lift sh...  requirement
# 3   Each pipe shall be transferred into the box e...  requirement
# 4   Each of the vrollers shall be used on many st...  requirement
#
#          document
# 0          SKAMid
# 1          SKAMid
# 2  JCanadaWelding
# 3  JCanadaWelding
# 4  JCanadaWelding

# %%
train_requs , test_requs , train_labels , test_labels = train_test_split (
requirements , labels , random_state =500 , test_size =.2)

# %%
#print(train_requs)

# %%
from bertopic import BERTopic
from hdbscan import HDBSCAN

hdbscan_model = HDBSCAN(min_cluster_size=5, metric='euclidean', cluster_selection_method='eom', prediction_data=True)
topic_model = BERTopic(hdbscan_model=hdbscan_model)

# %%
# The main representation of a topic
main_representation = KeyBERTInspired()


# Additional ways of representing a topic
aspect_model1 = PartOfSpeech("en_core_web_sm")
aspect_model2 = [KeyBERTInspired(top_n_words=30), MaximalMarginalRelevance(diversity=.5)]

# Add all models together to be run in a single `fit`
representation_model = {
   "Main": main_representation,
   "Aspect1":  aspect_model1,
   "Aspect2":  aspect_model2 
}
topic_model = BERTopic(representation_model=representation_model, hdbscan_model=hdbscan_model).fit(train_requs)
# Out:
# /projects/c7a1100d-10f9-4de1-b172-d38d7d09565f/.local/lib/python3.10/site-packages/numba/np/ufunc/parallel.py:371: NumbaWarning: The TBB threading layer requires TBB version 2021 update 6 or later i.e., TBB_INTERFACE_VERSION >= 12060. Found TBB_INTERFACE_VERSION = 12050. The TBB threading layer is disabled.
#   warnings.warn(problem)

# %%
topic_model.visualize_documents(train_requs)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="65528396-d539-4fd8-ad13-87f06f318c77" class="plotly-graph-div" style="height:750px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("65528396-d539-4fd8-ad13-87f06f318c77")) {                    Plotly.newPlot(                        "65528396-d539-4fd8-ad13-87f06f318c77",                        [{"hoverinfo":"text","hovertext":["When commanded, CSP_Mid.CBF shall, independently for each subarray and for any given Band, integrate visibilities within the processed bandwidth into separate repetitively-accumulated temporal phase bins and provide up to 1024 (TBC) such bins, with 4 choices of visibility spectral channel widths covering the range from 1 to 1024 times the standard wideband visibility channel width, allowing a programmable tradeoff between the pulsar period, number of phase bins (1, 2, 3, ..., 1024), spectral channel bandwidth (any of the selectable 4), and bin dwell time."," The vrollers of the box end threading inspection station shall then return to the up position and shall be prepared to accept the next pipe. ","All CSP_Mid.CBF connector plates shall carry identification labels for connectors.","The ieee802-dot1cb-mask-and-match YANG module defined in this standard provides an additional Stream identification functionality by augmenting the Stream identification functionality provided by the ieee802-dot1cb-stream-identification module"," Each box end drift and threading protector station paddle lift shall lower the pipe onto the box end drift and threading protector station vrollers. ","When commanded, CSP_Mid.CBF shall receive data from each SKA1 Mid DISH at the sample rates, Nbits\u002fsample, and resulting aggregate data rates specified per-Band in the DISH to CSP ICD.","Provisions for the preclusion of mounting the wrong module shall be provided (key coding of connectors etc.).","The DSH shall report serial numbers for hardware components that provide digitally readable serial numbers","When commanded, for each VLBI subarray, CSP_Mid.CBF shall form VLBI beams using any selected SKA1_Mid receptors in the subarray, with no limit to the separation of receptors in the subarray.","CSP_Mid.CBF rack and LRU equipment shall be RoHS\n2 (2011\u002f65\u002fEU) certified in accordance with the latest approved version of the MID CSP to INFRA ICD."," The project shall incorporate only pneumatic and electric actuators and none of them shall be hydraulic. ","The IXR for each SPF band shall be \u003e 15 dB within the -3 dB contour, over the whole observing bandwidth."," Special common carrier crating steel skidding or returnable containers or skids shall not be included in this proposal. ","Scarify the roadbed, including shoulders, to the specified depth and width. Pulverize the scari-\nfied material so that a minimum of 95 percent, excluding gravel or stone, passes a 2-in. (50-mm)\nsieve.","DSH shall not report alarms, events, logs, or faults on missing components.","Any component of the Dish shall not emit electromagnetic radiation between 50 MHz and 300 MHz, which produces a power spectral density, that is received by an isotropic receiver at a distance of 500m, that is greater than:\n- The Spectral Line power threshold levels defined by:\nof 0.001% of centre frequency.\n- The Continuum power threshold levels defined by:\nof 1% of centre frequency."," For a truly successful project the work performed must be properly documented for future maintenance and troubleshooting and your project documentation shall result in a lower Total Cost of Ownership  over the life of the equipment. ","Unless otherwise specified, standard practices as covered by the American Iron and Steel Institute in the latest revision of the AISI Steel Products Manual, Wire and Rods, Carbon St ...

# %%
topic_model.visualize_heatmap()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="219c41b1-6cda-450b-a4ce-b475666b917f" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("219c41b1-6cda-450b-a4ce-b475666b917f")) {                    Plotly.newPlot(                        "219c41b1-6cda-450b-a4ce-b475666b917f",                        [{"coloraxis":"coloraxis","name":"0","x":["0_retests_testing_retest","1_threading_line_dials","2_pipe_threaded_adjustable","3_dish_pointing_ranging","4_csp_telescope_timestamps","5_deactivation_hmis_hmi","6_safety_equipment_personnel","7_ghz_rf_hz","8_components_supplier_equip...","9_painted_paint_painting","10_wires_wire_coils","11_dsh_modes_mode","12_cspmidcbf_cspmidlmc_faults","13_mhz_pulsar_beamforming","14_dsh_enclosure_pedestal","15_iec_cspmidcbf_csp","16_beamchannels_beamchannel...","17_cooling_cooled_thermal","18_warranties_warranty_warr...","19_precision_pointing_circle","20_pipe_tests_bend","21_cspmidcbf_csp_icd","22_welded_structural_frame","23_pipe_blast_pneumatic","24_tooling_tools_equipment","25_planning_scheduled_meeti...","26_welded_tube_commissioning","27_mixture_density_mixing","28_pipe_vrollers_inspection","29_pipe_transferred_transfer","30_requirements_specificati...","31_cspmidcbf_midcbf_labelling","32_wiring_wires_relays","33_ska1sysreq2180_ska1mid_s...","34_suppliers_supplier_contr...","35_dsh_monitoring_reporting","36_csp_cspmidcbf_ska1","37_creel_assembly_assemblies","38_pipe_pushbutton_pushbutt...","39_clearance_workbench_work...","40_packets_packet_bytes","41_ska1_ska1mid_rms","42_pipelines_pipeline_pipe","43_pipe_cnc_pipes","44_plcs_plc_controls","45_dsh_firmware_maintenance","46_markings_marking_labelled","47_criteria_fat_equipment","48_bobbins_bobbin_spindle","49_pipe_vrollers_drop","50_feeders_feeding_feeder","51_disc_electrode_surface","52_nameplate_equipment_stai...","53_downstream_station_upstr...","54_yarn_bobbins_bobbin","55_packaging_srus_packaged","56_valves_vents_inlet","57_grippers_gripper_gripper...","58_aec_audits_design","59_languagepreferredcompone...","60_transfer_table_pipe","61_protocol_api_requesturi","62_spindles_spindle_bearings","63_iec62305_lightning_iec","64_stations_station_pallet","65_lift_paddle_pipe","66_cspmidcbf_frequency_band..."],"y":["0_retests_testing_retest","1_threading_line_dials","2_pipe_threaded_adjustable","3_dish_pointing_ranging","4_csp_telescope_timestamps","5_deactivation_hmis_hmi","6_safety_equipment_personnel","7_ghz_rf_hz","8_components_supplier_equip...","9_painted_paint_painting","10_wires_wire_coils","11_dsh_modes_mode","12_cspmidcbf_cspmidlmc_faults","13_mhz_pulsar_beamforming","14_dsh_enclosure_pedestal","15_iec_cspmidcbf_csp","16_beamchannels_beamchannel...","17_cooling_cooled_thermal","18_warranties_warranty_warr...","19_precision_pointing_circle","20_pipe_tests_bend","21_cspmidcbf_csp_icd","22_welded_structural_frame","23_pipe_blast_pneumatic","24_tooling_tools_equipment","25_planning_scheduled_meeti...","26_welded_tube_commissioning","27_mixture_density_mixing","28_pipe_vrollers_inspection","29_pipe_transferred_transfer","30_requirements_specificati...","31_cspmidcbf_midcbf_labelling","32_wiring_wires_relays","33_ska1sysreq2180_ska1mid_s...","34_suppliers_supplier_contr...","35_dsh_monitoring_reporting","36_csp_cspmidcbf_ska1","37_creel_assembly_assemblies","38_pipe_pushbutton_pushbutt...","39_clearance_workbench_work...","40_packets_packet_bytes","41_ska1_ska1mid_rms","42_pipelines_pipeline_pipe","43_pipe_cnc_pipes","44_plcs_plc_controls","45_dsh_firmware_maintenance","46_markings_marking_labelled","47_criteria_fat_equipment","48_bobbins_bobbin_spindle","49_pipe_vrollers_drop","50_feeders_feeding_feeder","51_disc_electrode_surface","52_nameplate_equipment_stai...","53_downstream_station_up ...

# %%
topic_model.visualize_hierarchical_documents()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 topic_model.visualize_hierarchical_documents()
#
# TypeError: BERTopic.visualize_hierarchical_documents() missing 2 required positional arguments: 'docs' and 'hierarchical_topics'

# %%
import pandas as pd

topic_embeddings = topic_model.get_topic_info()

# Create a DataFrame from the topic embeddings
df = pd.DataFrame(topic_embeddings)

# Save the DataFrame to a CSV file
df.to_csv('topic_embeddings.csv', index=False)

# %%
hierarchical_topics = topic_model.hierarchical_topics(train_requs)
tree = topic_model.get_topic_tree(hierarchical_topics)
print(tree)

import matplotlib.pyplot as plt
import networkx as nx

# Assuming `tree` is the topic tree
G = nx.DiGraph(tree)
pos = nx.nx_agraph.graphviz_layout(G, prog='dot')

plt.figure(figsize=(10, 10))
nx.draw(G, pos, with_labels=True)
plt.savefig('topic_tree.png')
plt.show()
# Out:
#   0%|          | 0/28 [00:00<?, ?it/s]
#  11%|█         | 3/28 [00:00<00:00, 25.94it/s]
#  21%|██▏       | 6/28 [00:00<00:00, 25.54it/s]
#  32%|███▏      | 9/28 [00:00<00:00, 24.67it/s]
#  43%|████▎     | 12/28 [00:00<00:00, 24.46it/s]
#  54%|█████▎    | 15/28 [00:00<00:00, 24.24it/s]
#  64%|██████▍   | 18/28 [00:00<00:00, 24.59it/s]
#  75%|███████▌  | 21/28 [00:00<00:00, 24.27it/s]
#  86%|████████▌ | 24/28 [00:00<00:00, 23.84it/s]
#  96%|█████████▋| 27/28 [00:01<00:00, 22.61it/s]
# 100%|██████████| 28/28 [00:01<00:00, 23.70it/s]
# .
# ├─mhz_frequency_range_precision_mid
# │    ├─csp_cspmidcbf_mhz_cspmidlmc_frequency
# │    │    ├─beamchannel_csp_mhz_cspmidcbf_rfi
# │    │    │    ├─■──mhz_pulsar_beamforming_frequency_beam ── Topic: 16
# │    │    │    └─csp_cspmidcbf_mhz_frequency_rfi
# │    │    │         ├─■──beamchannels_beamchannel_rfi_mhz_bandwidths ── Topic: 12
# │    │    │         └─■──csp_cspmidcbf_cspmidlmc_frequency_receptor ── Topic: 4
# │    │    └─iec_cspmidcbf_csp_cpf_compliant
# │    │         ├─■──cspmidcbf_csp_icd_sdp_is1msdpcsp001 ── Topic: 6
# │    │         └─■──iec_cspmidcbf_csp_cpf_mid ── Topic: 2
# │    └─sensitivity_ska1mid_range_rms_precision
# │         ├─ska1mid_sensitivity_polarization_dish_range
# │         │    ├─■──dsh_tm_monitoring_mode_modes ── Topic: 1
# │         │    └─ska1mid_sensitivity_polarization_dish_range
# │         │         ├─■──dish_pointing_ranging_tracking_coordinates ── Topic: 9
# │         │         └─■──ska1_ska1mid_sensitivity_polarization_dish ── Topic: 10
# │         └─■──precision_pointing_circle_perreceptor_arcsec ── Topic: 18
# └─pipe_threading_lift_adjustable_welded
#      ├─specification_testing_tests_specimen_specimens
#      │    ├─supplier_components_equipment_manufacturing_assemblies
#      │    │    ├─components_supplier_equipment_manufacturing_packages
#      │    │    │    ├─■──requirements_specifications_documents_manuals_requirement ── Topic: 26
#      │    │    │    └─■──components_supplier_equipment_yarn_documents ── Topic: 15
#      │    │    └─loaders_creel_loader_bobbins_spindle
#      │    │         ├─■──creel_assembly_assemblies_supplier_assembled ── Topic: 27
#      │    │         └─■──bobbins_yarn_bobbin_spools_spool ── Topic: 20
#      │    └─tests_testing_test_specimen_specimens
#      │         ├─testing_tests_test_specimen_specification
#      │         │    ├─testing_tests_retest_test_specification
#      │         │    │    ├─■──warranties_warranty_warrants_repair_maintenance ── Topic: 17
#      │         │    │    └─testing_tests_test_retest_specimen
#      │         │    │         ├─testing_tests_retest_test_specification
#      │         │    │         │    ├─■──pipelines_pipe_tests_specimen_trench ── Topic: 5
#      │         │    │         │    └─■──retests_testing_retest_test_specimen ── Topic: 3
#      │         │    │         └─equipment_safety_personnel_inspections_mechanical
#      │         │    │              ├─■──suppliers_supplier_inspections_fabrication_purchasers ── Topic: 22
#      │         │    │              └─■──safety_equipment_personnel_ergonomics_guards ── Topic: 7
#      │         │    └─welded_tube_construction_components_structural
#      │         │         ├─welded_commissioning_tube_configuration_setup
#      │         │         │    ├─tooling_equipment_tools_components_parts
#      │         │         │    │    ├─■──tooling_tools_equipment_components_features ── Topic: 21
#      │         │         │    │    └─■──station_stations_downstream_upstream_parts ── Topic: 28
#      │         │         │    └─welded_commissioning_tube_configuration_equipment
#      │         │         │         ├─■──aec_design_engineering_project_audits ── Topic: 11
#      │         │         │         └─■──welded_tube_commissioning_equipment_contracting ── Topic: 23
#      │         │         └─welded_structural_frame_structures_construction
#      │         │              ├─■──welded_structural_frame_frames_constructed ── Topic: 24
#      │         │              └─■──painted_paint_painting_steel_coat ── Topic: 14
#      │         └─deactivation_relays_switches_wiring_wires
#      │              ├─■──wires_wire_coils_wiring_coil ── Topic: 19
#      │              └─deactivation_wiring_relays_switches_hmis
#      │                   ├─■──wiring_24v_relays_480v_wires ── Topic: 25
#      │                   └─■──deactivation_hmis_hmi_timers_switches ── Topic: 13
#      └─pipe_lift_lowered_lifting_lifted
#           ├─■──pipe_lift_lowered_lifting_lifted ── Topic: 0
#           └─■──threading_line_inspection_pipe_stations ── Topic: 8
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/networkx/convert.py:158, in to_networkx_graph(data, create_using, multigraph_input)
#     157 try:
# --> 158     return nx.from_scipy_sparse_array(data, create_using=create_using)
#     159 except Exception as err:
#
# File ~/.local/lib/python3.10/site-packages/networkx/convert_matrix.py:728, in from_scipy_sparse_array(A, parallel_edges, create_using, edge_attribute)
#     727 G = nx.empty_graph(0, create_using)
# --> 728 n, m = A.shape
#     729 if n != m:
#
# AttributeError: 'str' object has no attribute 'shape'
#
# The above exception was the direct cause of the following exception:
#
# NetworkXError                             Traceback (most recent call last)
# Cell In[11], line 9
#       6 import networkx as nx
#       8 # Assuming `tree` is the topic tree
# ----> 9 G = nx.DiGraph(tree)
#      10 pos = nx.nx_agraph.graphviz_layout(G, prog='dot')
#      12 plt.figure(figsize=(10, 10))
#
# File ~/.local/lib/python3.10/site-packages/networkx/classes/digraph.py:360, in DiGraph.__init__(self, incoming_graph_data, **attr)
#     356 # Note: self._succ = self._adj  # successor
#     357
#     358 # attempt to load graph with data
#     359 if incoming_graph_data is not None:
# --> 360     convert.to_networkx_graph(incoming_graph_data, create_using=self)
#     361 # load graph attributes (must be after convert)
#     362 self.graph.update(attr)
#
# File ~/.local/lib/python3.10/site-packages/networkx/convert.py:160, in to_networkx_graph(data, create_using, multigraph_input)
#     158             return nx.from_scipy_sparse_array(data, create_using=create_using)
#     159         except Exception as err:
# --> 160             raise nx.NetworkXError(
#     161                 "Input is not a correct scipy sparse array type."
#     162             ) from err
#     163 except ImportError:
#     164     warnings.warn("scipy not found, skipping conversion test.", ImportWarning)
#
# NetworkXError: Input is not a correct scipy sparse array type.

# %%
import pandas as pd

# Call the get_topic_info() method and save the output
topic_info = topic_model.get_topic_info()


# Convert the output to a pandas DataFrame
df = pd.DataFrame(topic_info)


# Save the DataFrame to a CSV file
df.to_csv('topic_info.csv', index=False)

# %%
topic_model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="db393a49-a8ab-46a5-9061-bb3fc7094d5f" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("db393a49-a8ab-46a5-9061-bb3fc7094d5f")) {                    Plotly.newPlot(                        "db393a49-a8ab-46a5-9061-bb3fc7094d5f",                        [{"customdata":[[0,"pipe | lift | lowered | lifting | lifted",148],[1,"dsh | tm | monitoring | mode | modes",86],[2,"iec | cspmidcbf | csp | cpf | mid",86],[3,"retests | testing | retest | test | specimen",58],[4,"csp | cspmidcbf | cspmidlmc | frequency | receptor",48],[5,"pipelines | pipe | tests | specimen | trench",47],[6,"cspmidcbf | csp | icd | sdp | is1msdpcsp001",47],[7,"safety | equipment | personnel | ergonomics | guards",38],[8,"threading | line | inspection | pipe | stations",36],[9,"dish | pointing | ranging | tracking | coordinates",32],[10,"ska1 | ska1mid | sensitivity | polarization | dish",31],[11,"aec | design | engineering | project | audits",30],[12,"beamchannels | beamchannel | rfi | mhz | bandwidths",30],[13,"deactivation | hmis | hmi | timers | switches",24],[14,"painted | paint | painting | steel | coat",20],[15,"components | supplier | equipment | yarn | documents",19],[16,"mhz | pulsar | beamforming | frequency | beam",19],[17,"warranties | warranty | warrants | repair | maintenance",18],[18,"precision | pointing | circle | perreceptor | arcsec",17],[19,"wires | wire | coils | wiring | coil",17],[20,"bobbins | yarn | bobbin | spools | spool",17],[21,"tooling | tools | equipment | components | features",15],[22,"suppliers | supplier | inspections | fabrication | purchasers",14],[23,"welded | tube | commissioning | equipment | contracting",14],[24,"welded | structural | frame | frames | constructed",14],[25,"wiring | 24v | relays | 480v | wires",13],[26,"requirements | specifications | documents | manuals | requirement",12],[27,"creel | assembly | assemblies | supplier | assembled",12],[28,"station | stations | downstream | upstream | parts",11]],"hovertemplate":"\u003cb\u003eTopic %{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e%{customdata[1]}\u003cbr\u003eSize: %{customdata[2]}","legendgroup":"","marker":{"color":"#B0BEC5","size":[148,86,86,58,48,47,47,38,36,32,31,30,30,24,20,19,19,18,17,17,17,15,14,14,14,13,12,12,11],"sizemode":"area","sizeref":0.0925,"symbol":"circle","line":{"color":"DarkSlateGrey","width":2}},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[-9.611334800720215,16.913619995117188,12.09782886505127,-0.30471140146255493,12.380000114440918,-0.5125133991241455,12.2639799118042,5.032437801361084,-9.51124382019043,16.743173599243164,16.46934700012207,10.894454956054688,12.438867568969727,17.07324981689453,5.305123329162598,11.707114219665527,12.244769096374512,11.155837059020996,12.660735130310059,-7.852384567260742,4.5654168128967285,5.103460788726807,11.110235214233398,4.934494972229004,4.964978218078613,-7.828924179077148,11.811139106750488,4.743251800537109,-9.314048767089844],"xaxis":"x","y":[-7.417784214019775,23.18267059326172,-1.1168835163116455,-5.284746170043945,-1.9430676698684692,-5.4843316078186035,-1.355560064315796,3.5541975498199463,-7.317703723907471,23.011842727661133,22.737964630126953,-14.70255184173584,-2.2524309158325195,23.342334747314453,12.28608512878418,-14.929530143737793,-2.4664535522460938,-14.96498966217041,-1.7117924690246582,19.044063568115234,12.710959434509277,3.4830877780914307,-14.897506713867188,11.88253402709961,12.195537567138672,19.06751823425293,-15.03095531463623,12.532760620117188,-7.120596408843994],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size": ...

# %%
df = topic_model.get_document_info(train_requs)
df.to_csv('document info', index=False)

# %%
topic_model.visualize_barchart()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="e3edee05-a17a-428a-b0e6-781e1abab1c9" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e3edee05-a17a-428a-b0e6-781e1abab1c9")) {                    Plotly.newPlot(                        "e3edee05-a17a-428a-b0e6-781e1abab1c9",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.30186235904693604,0.30303245782852173,0.3120971620082855,0.3485194444656372,0.5419715642929077],"y":["lifted  ","lifting  ","lowered  ","lift  ","pipe  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.27383774518966675,0.2933771014213562,0.3120797872543335,0.36906906962394714,0.6184616684913635],"y":["modes  ","mode  ","monitoring  ","tm  ","dsh  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.25209495425224304,0.4005003571510315,0.40738624334335327,0.41297411918640137,0.4331119656562805],"y":["mid  ","cpf  ","csp  ","cspmidcbf  ","iec  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.3942120671272278,0.4143597483634949,0.4598328471183777,0.46639886498451233,0.48726433515548706],"y":["specimen  ","test  ","retest  ","testing  ","retests  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.2693353593349457,0.2757544219493866,0.2890246510505676,0.3271726369857788,0.3633311986923218],"y":["receptor  ","frequency  ","cspmidlmc  ","cspmidcbf  ","csp  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.28985923528671265,0.289996862411499,0.315199077129364,0.46469467878341675,0.4673464000225067],"y":["trench  ","specimen  ","tests  ","pipe  ","pipelines  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.37191829085350037,0.3931090831756592,0.3983636796474457,0.4209269881248474,0.47359296679496765],"y":["is1msdpcsp001  ","sdp  ","icd  ","csp  ","cspmidcbf  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.35532253980636597,0.3618302345275879,0.416262686252594,0.5135224461555481,0.5341187119483948],"y":["guards  ","ergonomics  ","personnel  ","equipment  ","safety  "],"type":"bar","xaxis":"x8","yaxis":"y8"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.555555555 ...

# %%
topic_model.get_topic_info()
# Out:
#     Topic  Count                                              Name  \
# 0      -1    232                        -1_ghz_rf_frequency_signal
# 1       0    148                       0_pipe_lift_lowered_lifting
# 2       1     86                          1_dsh_tm_monitoring_mode
# 3       2     86                           2_iec_cspmidcbf_csp_cpf
# 4       3     58                     3_retests_testing_retest_test
# 5       4     48               4_csp_cspmidcbf_cspmidlmc_frequency
# 6       5     47                   5_pipelines_pipe_tests_specimen
# 7       6     47                           6_cspmidcbf_csp_icd_sdp
# 8       7     38           7_safety_equipment_personnel_ergonomics
# 9       8     36                  8_threading_line_inspection_pipe
# 10      9     32                  9_dish_pointing_ranging_tracking
# 11     10     31          10_ska1_ska1mid_sensitivity_polarization
# 12     11     30                 11_aec_design_engineering_project
# 13     12     30               12_beamchannels_beamchannel_rfi_mhz
# 14     13     24                   13_deactivation_hmis_hmi_timers
# 15     14     20                   14_painted_paint_painting_steel
# 16     15     19             15_components_supplier_equipment_yarn
# 17     16     19               16_mhz_pulsar_beamforming_frequency
# 18     17     18            17_warranties_warranty_warrants_repair
# 19     18     17          18_precision_pointing_circle_perreceptor
# 20     19     17                        19_wires_wire_coils_wiring
# 21     20     17                     20_bobbins_yarn_bobbin_spools
# 22     21     15             21_tooling_tools_equipment_components
# 23     22     14     22_suppliers_supplier_inspections_fabrication
# 24     23     14            23_welded_tube_commissioning_equipment
# 25     24     14                 24_welded_structural_frame_frames
# 26     25     13                         25_wiring_24v_relays_480v
# 27     26     12  26_requirements_specifications_documents_manuals
# 28     27     12             27_creel_assembly_assemblies_supplier
# 29     28     11           28_station_stations_downstream_upstream
#
#                                        Representation  \
# 0   [ghz, rf, frequency, signal, station, band, re...
# 1   [pipe, lift, lowered, lifting, lifted, conveyo...
# 2   [dsh, tm, monitoring, mode, modes, capability,...
# 3   [iec, cspmidcbf, csp, cpf, mid, compliant, ele...
# 4   [retests, testing, retest, test, specimen, spe...
# 5   [csp, cspmidcbf, cspmidlmc, frequency, recepto...
# 6   [pipelines, pipe, tests, specimen, trench, tes...
# 7   [cspmidcbf, csp, icd, sdp, is1msdpcsp001, inte...
# 8   [safety, equipment, personnel, ergonomics, gua...
# 9   [threading, line, inspection, pipe, stations, ...
# 10  [dish, pointing, ranging, tracking, coordinate...
# 11  [ska1, ska1mid, sensitivity, polarization, dis...
# 12  [aec, design, engineering, project, audits, ap...
# 13  [beamchannels, beamchannel, rfi, mhz, bandwidt...
# 14  [deactivation, hmis, hmi, timers, switches, se...
# 15  [painted, paint, painting, steel, coat, surfac...
# 16  [components, supplier, equipment, yarn, docume...
# 17  [mhz, pulsar, beamforming, frequency, beam, cs...
# 18  [warranties, warranty, warrants, repair, maint...
# 19  [precision, pointing, circle, perreceptor, arc...
# 20  [wires, wire, coils, wiring, coil, splices, te...
# 21  [bobbins, yarn, bobbin, spools, spool, spindle...
# 22  [tooling, tools, equipment, components, featur...
# 23  [suppliers, supplier, inspections, fabrication...
# 24  [welded, tube, commissioning, equipment, contr...
# 25  [welded, structural, frame, frames, constructe...
# 26  [wiring, 24v, relays, 480v, wires, 208vac, col...
# 27  [requirements, specifications, documents, manu...
# 28  [creel, assembly, assemblies, supplier, assemb...
# 29  [station, stations, downstream, upstream, part...
#
#                                               Aspect1  \
# 0   [band, frequency, number, rf, part, power, dat...
# 1   [pipe, station, end, vrollers, box, stop, thre...
# 2   [conditions, lightning, mode, state, equipment...
# 3   [latest, version, accordance, equipment, air, ...
# 4   [test, castings, specimen, specification, cast...
# 5   [subarray, receptor, time, delay, receptors, p...
# 6   [pipe, in, concrete, mm, diameter, test, lengt...
# 7   [interface, packet, section, compliant, packet...
# 8   [personnel, equipment, safety, floor, system, ...
# 9   [threading, station, end, line, box, pin, dope...
# 10  [dish, pointing, element, model, elevation, tr...
# 11  [dish, band, sensitivity, operating, channels,...
# 12  [project, design, customer, schedule, delivery...
# 13  [bandwidth, channel, frequency, visibility, sa...
# 14  [cylinder, time, manual, error, sensors, statu...
# 15  [steel, coat, suitable, construction, paint, s...
# 16  [data, following, controls, major, documents, ...
# 17  [beamforming, beams, bandwidth, least, form, c...
# 18  [warranty, seller, products, errors, software,...
# 19  [pointing, arcsec, circle, performance, total,...
# 20  [wire, coil, ft, coils, wiring, junction, ends...
# 21  [yarn, bobbin, creel, mm, inches, bobbins, spi...
# 22  [tooling, incorrect, tools, fixtures, parts, o...
# 23  [purchaser, approval, tests, fabrication, perf...
# 24  [tube, responsible, installation, supply, site...
# 25  [structural, frame, members, frames, station, ...
# 26  [dc, blue, control, switches, wiring, relays, ...
# 27  [data, documents, pack, requirements, followin...
# 28  [creel, bobbins, supplier, aisle, line, assemb...
# 29  [pallet, number, parts, station, shift, statio...
#
#                                               Aspect2  \
# 0   [ghz, rf, frequency, signal, receptor, languag...
# 1   [pipe, lift, conveyor, adjustable, mechanism, ...
# 2   [dsh, tm, monitoring, modes, capability, comma...
# 3   [iec, cspmidcbf, radiated, emiemc, standards, ...
# 4   [retests, specification, specimens, casting, h...
# 5   [cspmidlmc, frequency, receptor, delay, utc, s...
# 6   [pipelines, tests, trench, thickness, flatteni...
# 7   [cspmidcbf, icd, sdp, is1msdpcsp001, protocol,...
# 8   [equipment, personnel, ergonomics, guards, pro...
# 9   [threading, inspection, pipe, stations, pin, a...
# 10  [dish, ranging, axis, elevation, precision, mo...
# 11  [ska1, sensitivity, polarization, channels, sp...
# 12  [aec, design, audits, approval, scheduled, mee...
# 13  [beamchannels, rfi, mhz, resolution, cspmidlmc...
# 14  [deactivation, hmis, timers, switches, mode, p...
# 15  [paint, surfaces, enamel, specification, gloss...
# 16  [components, supplier, equipment, yarn, docume...
# 17  [mhz, pulsar, beamforming, cspmidcbf, rfi, cha...
# 18  [warranties, repair, merchantability, liabilit...
# 19  [precision, circle, perreceptor, arcsec, rms, ...
# 20  [wires, coil, splices, crimp, distributor, sto...
# 21  [bobbins, yarn, spools, spindles, loaders, cre...
# 22  [tooling, equipment, features, replacing, fixt...
# 23  [suppliers, inspections, purchaser, requiremen...
# 24  [welded, commissioning, equipment, contracting...
# 25  [welded, structural, frames, extrusions, brace...
# 26  [wiring, 24v, relays, colors, 1020vac, panels,...
# 27  [requirements, specifications, manuals, instru...
# 28  [creel, assemblies, components, sketch, loader...
# 29  [stations, downstream, throughput, ftq, waits,...
#
#                                   Representative_Docs
# 0   [When commanded and processing data from Band ...
# 1   [ Each pipe shall gravity roll to the adjustab...
# 2   [TM shall control DSH using the DSH external s...
# 3   [CSP_Mid.CBF equipment connected to the CPF el...
# 4   [If the results of a valid test fail to confor...
# 5   [When commanded, CSP_Mid.CBF shall report at l...
# 6   [The flattening test of Specification A530/A53...
# 7   [The visibility interface between SDP and CSP_...
# 8   [The Supplier's equipment and system shall be ...
# 9   [ Each threading line shall have a box end end...
# 10  [The dish element shall achieve full performan...
# 11  [The sensitivity of a SKA1_Mid dish shall not ...
# 12  [ Engineering design documents shall be submit...
# 13  [When commanded, independently within each Fre...
# 14  [each station can be switched off bypassed sep...
# 15  [Unless otherwise specified, standard practice...
# 16  [The Supplier shall furnish all equipment, con...
# 17  [For any Band and for each Pulsar Timing beam,...
# 18  [ The seller shall not warranty standard maint...
# 19  [The total per-receptor Relative Pointing Erro...
# 20  [The container shall also carry, in a differen...
# 21  [Full PAN bobbins will be loaded on the Creel ...
# 22  [equipment shall detect tooling type and incor...
# 23  [Prior to starting fabrication the Supplier an...
# 24  [ Welded Tube shall be responsible for the sup...
# 25  [ Each box end threading inspection station fr...
# 26  [all control voltage will be regulated 24v dc....
# 27  [All Engineering documents and data listed in ...
# 28  [The Creel frames shall be configured with thr...
# 29  [total parts ñ total number of parts by shift ...

# %%
topic_model.visualize_heatmap()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="1dbf3c78-2605-4589-a91d-d11d42ebb613" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1dbf3c78-2605-4589-a91d-d11d42ebb613")) {                    Plotly.newPlot(                        "1dbf3c78-2605-4589-a91d-d11d42ebb613",                        [{"coloraxis":"coloraxis","name":"0","x":["0_pipe_lift_lowered","1_dsh_tm_monitoring","2_iec_cspmidcbf_csp","3_retests_testing_retest","4_csp_cspmidcbf_cspmidlmc","5_pipelines_pipe_tests","6_cspmidcbf_csp_icd","7_safety_equipment_personnel","8_threading_line_inspection","9_dish_pointing_ranging","10_ska1_ska1mid_sensitivity","11_aec_design_engineering","12_beamchannels_beamchannel...","13_deactivation_hmis_hmi","14_painted_paint_painting","15_components_supplier_equi...","16_mhz_pulsar_beamforming","17_warranties_warranty_warr...","18_precision_pointing_circle","19_wires_wire_coils","20_bobbins_yarn_bobbin","21_tooling_tools_equipment","22_suppliers_supplier_inspe...","23_welded_tube_commissioning","24_welded_structural_frame","25_wiring_24v_relays","26_requirements_specificati...","27_creel_assembly_assemblies","28_station_stations_downstr..."],"y":["0_pipe_lift_lowered","1_dsh_tm_monitoring","2_iec_cspmidcbf_csp","3_retests_testing_retest","4_csp_cspmidcbf_cspmidlmc","5_pipelines_pipe_tests","6_cspmidcbf_csp_icd","7_safety_equipment_personnel","8_threading_line_inspection","9_dish_pointing_ranging","10_ska1_ska1mid_sensitivity","11_aec_design_engineering","12_beamchannels_beamchannel...","13_deactivation_hmis_hmi","14_painted_paint_painting","15_components_supplier_equi...","16_mhz_pulsar_beamforming","17_warranties_warranty_warr...","18_precision_pointing_circle","19_wires_wire_coils","20_bobbins_yarn_bobbin","21_tooling_tools_equipment","22_suppliers_supplier_inspe...","23_welded_tube_commissioning","24_welded_structural_frame","25_wiring_24v_relays","26_requirements_specificati...","27_creel_assembly_assemblies","28_station_stations_downstr..."],"z":[[1.0000001192092896,0.2796785533428192,0.2357071042060852,0.2504236698150635,0.1575973927974701,0.5633760690689087,0.24226292967796326,0.4069952964782715,0.6623611450195312,0.23452597856521606,0.09014040231704712,0.3428446054458618,0.16957418620586395,0.376617431640625,0.2380005270242691,0.25718072056770325,0.1778615415096283,0.12485816329717636,0.08158436417579651,0.33236533403396606,0.4474782943725586,0.41531288623809814,0.313555508852005,0.5786961317062378,0.4719995856285095,0.20833316445350647,0.18076683580875397,0.3304843008518219,0.44503897428512573],[0.2796785533428192,0.9999997019767761,0.32079046964645386,0.24746721982955933,0.2960454821586609,0.24428384006023407,0.4014835059642792,0.3825972080230713,0.3320751488208771,0.5776020884513855,0.3144562840461731,0.3684525489807129,0.21938885748386383,0.48861420154571533,0.21319177746772766,0.3011017143726349,0.19338461756706238,0.2601718306541443,0.1993838995695114,0.2244856208562851,0.09556281566619873,0.3649230897426605,0.34662503004074097,0.3026629686355591,0.22309967875480652,0.33377572894096375,0.3496251702308655,0.1641712188720703,0.27771592140197754],[0.2357071042060852,0.32079046964645386,0.9999999403953552,0.3769366145133972,0.730866014957428,0.3629564046859741,0.7403173446655273,0.41079580783843994,0.26229923963546753,0.26451343297958374,0.25115105509757996,0.34838518500328064,0.683405876159668,0.2474675178527832,0.32374483346939087,0.3018563985824585,0.5960274934768677,0.2725145220756531,0.21189406514167786,0.28497302532196045,0.2377236783504486,0.30992674827575684,0.3766292929649353,0.36086326837539673,0.32144492864608765,0.3428683280944824,0.3351142406463623,0.34600239992141724,0.26692116260528564],[0.2504236698150635,0.24746721982955933,0.3769366145133972, ...

# %%
topics, probs = topic_model.transform(test_requs)

# %%
# Calculate the topic distributions on a token-level
topic_distr, topic_token_distr = topic_model.approximate_distribution(train_requs, calculate_tokens=True)

# %%
topic_model.visualize_distribution(topic_distr[3])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="490eda39-e889-4b3d-aa20-fd93b046b081" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("490eda39-e889-4b3d-aa20-fd93b046b081")) {                    Plotly.newPlot(                        "490eda39-e889-4b3d-aa20-fd93b046b081",                        [{"marker":{"color":"#C8D2D7","line":{"color":"#6E8484","width":1}},"orientation":"h","x":[0.05146503025234224,0.036987091211786616,0.040889813125599514,0.2519710433236757,0.04128955992436666,0.08892176782259427,0.1965738557118145,0.03782145951957544,0.04695740307169577,0.0467878686012395,0.036988950652315736,0.040029798133915835,0.08331635864907824],"y":["\u003cb\u003eTopic 6\u003c\u002fb\u003e: warranties_warranty_warr...","\u003cb\u003eTopic 11\u003c\u002fb\u003e: mixture_density_mixing_...","\u003cb\u003eTopic 21\u003c\u002fb\u003e: tooling_tools_equipment...","\u003cb\u003eTopic 24\u003c\u002fb\u003e: cspmidcbf_cspmidlmc_fau...","\u003cb\u003eTopic 28\u003c\u002fb\u003e: cspmidcbf_cspmidlmcprov...","\u003cb\u003eTopic 33\u003c\u002fb\u003e: hardness_steel_alloys_i...","\u003cb\u003eTopic 50\u003c\u002fb\u003e: criteria_fat_equipment_...","\u003cb\u003eTopic 57\u003c\u002fb\u003e: nameplate_equipment_sta...","\u003cb\u003eTopic 58\u003c\u002fb\u003e: cspmidcbf_markings_pack...","\u003cb\u003eTopic 62\u003c\u002fb\u003e: steel_metallic_metal_ma...","\u003cb\u003eTopic 64\u003c\u002fb\u003e: pipe_process_vrollers_i...","\u003cb\u003eTopic 67\u003c\u002fb\u003e: expenses_expense_suppli...","\u003cb\u003eTopic 68\u003c\u002fb\u003e: pipe_tests_test_specime..."],"type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"hist ...

# %%
# Calculate the topic distributions on a token-level
topic_distr, topic_token_distr = topic_model.approximate_distribution(test_requs, calculate_tokens=True)

# Visualize the token-level distributions
df = topic_model.visualize_approximate_distribution(test_requs[3], topic_token_distr[3])
df
# Out:
#                                                      Steel     cast   \
# 6_warranties_warranty_warrants_repair             0.000000  0.000000
# 11_mixture_density_mixing_cement                  0.000000  0.000000
# 21_tooling_tools_equipment_components             0.000000  0.000000
# 24_cspmidcbf_cspmidlmc_faults_maintenance         0.000000  0.000000
# 28_cspmidcbf_cspmidlmcprovided_phasebinned_phase  0.000000  0.000000
# 33_hardness_steel_alloys_iron                     0.134431  0.134431
# 50_criteria_fat_equipment_procedure               0.000000  0.000000
# 57_nameplate_equipment_stainless_supplier         0.102535  0.102535
# 58_cspmidcbf_markings_packaging_labelled          0.000000  0.000000
# 62_steel_metallic_metal_materials                 0.126843  0.126843
# 64_pipe_process_vrollers_inspection               0.000000  0.000000
# 67_expenses_expense_supplier_costs                0.000000  0.000000
# 68_pipe_tests_test_specimen                       0.000000  0.000000
#
#                                                       in    ingots     \
# 6_warranties_warranty_warrants_repair             0.139523   0.139523
# 11_mixture_density_mixing_cement                  0.100273   0.100273
# 21_tooling_tools_equipment_components             0.110853   0.110853
# 24_cspmidcbf_cspmidlmc_faults_maintenance         0.000000   0.000000
# 28_cspmidcbf_cspmidlmcprovided_phasebinned_phase  0.000000   0.000000
# 33_hardness_steel_alloys_iron                     0.134431   0.134431
# 50_criteria_fat_equipment_procedure               0.000000   0.000000
# 57_nameplate_equipment_stainless_supplier         0.102535   0.102535
# 58_cspmidcbf_markings_packaging_labelled          0.127303   0.127303
# 62_steel_metallic_metal_materials                 0.126843   0.126843
# 64_pipe_process_vrollers_inspection               0.000000   0.000000
# 67_expenses_expense_supplier_costs                0.000000   0.000000
# 68_pipe_tests_test_specimen                       0.119265   0.119265
#
#                                                     or      strand       \
# 6_warranties_warranty_warrants_repair             0.139523     0.139523
# 11_mixture_density_mixing_cement                  0.100273     0.100273
# 21_tooling_tools_equipment_components             0.110853     0.110853
# 24_cspmidcbf_cspmidlmc_faults_maintenance         0.000000     0.000000
# 28_cspmidcbf_cspmidlmcprovided_phasebinned_phase  0.000000     0.000000
# 33_hardness_steel_alloys_iron                     0.000000     0.000000
# 50_criteria_fat_equipment_procedure               0.000000     0.000000
# 57_nameplate_equipment_stainless_supplier         0.000000     0.000000
# 58_cspmidcbf_markings_packaging_labelled          0.127303     0.127303
# 62_steel_metallic_metal_materials                 0.000000     0.000000
# 64_pipe_process_vrollers_inspection               0.000000     0.000000
# 67_expenses_expense_supplier_costs                0.000000     0.000000
# 68_pipe_tests_test_specimen                       0.119265     0.119265
#
#                                                   cast        is         \
# 6_warranties_warranty_warrants_repair                    0.0        0.0
# 11_mixture_density_mixing_cement                         0.0        0.0
# 21_tooling_tools_equipment_components                    0.0        0.0
# 24_cspmidcbf_cspmidlmc_faults_maintenance                0.0        0.0
# 28_cspmidcbf_cspmidlmcprovided_phasebinned_phase         0.0        0.0
# 33_hardness_steel_alloys_iron                            0.0        0.0
# 50_criteria_fat_equipment_procedure                      0.0        0.0
# 57_nameplate_equipment_stainless_supplier                0.0        0.0
# 58_cspmidcbf_markings_packaging_labelled                 0.0        0.0
# 62_steel_metallic_metal_materials                        0.0        0.0
# 64_pipe_process_vrollers_inspection                      0.0        0.0
# 67_expenses_expense_supplier_costs                       0.0        0.0
# 68_pipe_tests_test_specimen                              0.0        0.0
#
#                                                   permissible          \
# 6_warranties_warranty_warrants_repair                             0.0
# 11_mixture_density_mixing_cement                                  0.0
# 21_tooling_tools_equipment_components                             0.0
# 24_cspmidcbf_cspmidlmc_faults_maintenance                         0.0
# 28_cspmidcbf_cspmidlmcprovided_phasebinned_phase                  0.0
# 33_hardness_steel_alloys_iron                                     0.0
# 50_criteria_fat_equipment_procedure                               0.0
# 57_nameplate_equipment_stainless_supplier                         0.0
# 58_cspmidcbf_markings_packaging_labelled                          0.0
# 62_steel_metallic_metal_materials                                 0.0
# 64_pipe_process_vrollers_inspection                               0.0
# 67_expenses_expense_supplier_costs                                0.0
# 68_pipe_tests_test_specimen                                       0.0
#
#                                                   When           ...  \
# 6_warranties_warranty_warrants_repair                       0.0  ...
# 11_mixture_density_mixing_cement                            0.0  ...
# 21_tooling_tools_equipment_components                       0.0  ...
# 24_cspmidcbf_cspmidlmc_faults_maintenance                   0.0  ...
# 28_cspmidcbf_cspmidlmcprovided_phasebinned_phase            0.0  ...
# 33_hardness_steel_alloys_iron                               0.0  ...
# 50_criteria_fat_equipment_procedure                         0.0  ...
# 57_nameplate_equipment_stainless_supplier                   0.0  ...
# 58_cspmidcbf_markings_packaging_labelled                    0.0  ...
# 62_steel_metallic_metal_materials                           0.0  ...
# 64_pipe_process_vrollers_inspection                         0.0  ...
# 67_expenses_expense_supplier_costs                          0.0  ...
# 68_pipe_tests_test_specimen                                 0.0  ...
#
#                                                   material                                  \
# 6_warranties_warranty_warrants_repair                                             0.000000
# 11_mixture_density_mixing_cement                                                  0.000000
# 21_tooling_tools_equipment_components                                             0.000000
# 24_cspmidcbf_cspmidlmc_faults_maintenance                                         0.213313
# 28_cspmidcbf_cspmidlmcprovided_phasebinned_phase                                  0.000000
# 33_hardness_steel_alloys_iron                                                     0.000000
# 50_criteria_fat_equipment_procedure                                               0.000000
# 57_nameplate_equipment_stainless_supplier                                         0.000000
# 58_cspmidcbf_markings_packaging_labelled                                          0.000000
# 62_steel_metallic_metal_materials                                                 0.000000
# 64_pipe_process_vrollers_inspection                                               0.000000
# 67_expenses_expense_supplier_costs                                                0.000000
# 68_pipe_tests_test_specimen                                                       0.000000
#
#                                                   by                                   \
# 6_warranties_warranty_warrants_repair                                        0.000000
# 11_mixture_density_mixing_cement                                             0.000000
# 21_tooling_tools_equipment_components                                        0.000000
# 24_cspmidcbf_cspmidlmc_faults_maintenance                                    0.213313
# 28_cspmidcbf_cspmidlmcprovided_phasebinned_phase                             0.000000
# 33_hardness_steel_alloys_iron                                                0.000000
# 50_criteria_fat_equipment_procedure                                          0.131718
# 57_nameplate_equipment_stainless_supplier                                    0.000000
# 58_cspmidcbf_markings_packaging_labelled                                     0.000000
# 62_steel_metallic_metal_materials                                            0.000000
# 64_pipe_process_vrollers_inspection                                          0.000000
# 67_expenses_expense_supplier_costs                                           0.000000
# 68_pipe_tests_test_specimen                                                  0.000000
#
#                                                   any                                    \
# 6_warranties_warranty_warrants_repair                                          0.000000
# 11_mixture_density_mixing_cement                                               0.000000
# 21_tooling_tools_equipment_components                                          0.000000
# 24_cspmidcbf_cspmidlmc_faults_maintenance                                      0.108013
# 28_cspmidcbf_cspmidlmcprovided_phasebinned_phase                               0.000000
# 33_hardness_steel_alloys_iron                                                  0.000000
# 50_criteria_fat_equipment_procedure                                            0.261752
# 57_nameplate_equipment_stainless_supplier                                      0.000000
# 58_cspmidcbf_markings_packaging_labelled                                       0.000000
# 62_steel_metallic_metal_materials                                              0.000000
# 64_pipe_process_vrollers_inspection                                            0.000000
# 67_expenses_expense_supplier_costs                                             0.000000
# 68_pipe_tests_test_specimen                                                    0.000000
#
#                                                   estab_x0002_lished                                     \
# 6_warranties_warranty_warrants_repair                                                      0.000000
# 11_mixture_density_mixing_cement                                                           0.000000
# 21_tooling_tools_equipment_components                                                      0.000000
# 24_cspmidcbf_cspmidlmc_faults_maintenance                                                  0.000000
# 28_cspmidcbf_cspmidlmcprovided_phasebinned_phase                                           0.000000
# 33_hardness_steel_alloys_iron                                                              0.000000
# 50_criteria_fat_equipment_procedure                                                        0.397334
# 57_nameplate_equipment_stainless_supplier                                                  0.000000
# 58_cspmidcbf_markings_packaging_labelled                                                   0.000000
# 62_steel_metallic_metal_materials                                                          0.000000
# 64_pipe_process_vrollers_inspection                                                        0.000000
# 67_expenses_expense_supplier_costs                                                         0.000000
# 68_pipe_tests_test_specimen                                                                0.000000
#
#                                                   procedure                                      \
# 6_warranties_warranty_warrants_repair                                                  0.000000
# 11_mixture_density_mixing_cement                                                       0.000000
# 21_tooling_tools_equipment_components                                                  0.000000
# 24_cspmidcbf_cspmidlmc_faults_maintenance                                              0.000000
# 28_cspmidcbf_cspmidlmcprovided_phasebinned_phase                                       0.000000
# 33_hardness_steel_alloys_iron                                                          0.000000
# 50_criteria_fat_equipment_procedure                                                    0.532916
# 57_nameplate_equipment_stainless_supplier                                              0.000000
# 58_cspmidcbf_markings_packaging_labelled                                               0.000000
# 62_steel_metallic_metal_materials                                                      0.000000
# 64_pipe_process_vrollers_inspection                                                    0.000000
# 67_expenses_expense_supplier_costs                                                     0.000000
# 68_pipe_tests_test_specimen                                                            0.000000
#
#                                                   that                                       \
# 6_warranties_warranty_warrants_repair                                              0.000000
# 11_mixture_density_mixing_cement                                                   0.000000
# 21_tooling_tools_equipment_components                                              0.000000
# 24_cspmidcbf_cspmidlmc_faults_maintenance                                          0.000000
# 28_cspmidcbf_cspmidlmcprovided_phasebinned_phase                                   0.111937
# 33_hardness_steel_alloys_iron                                                      0.000000
# 50_criteria_fat_equipment_procedure                                                0.401198
# 57_nameplate_equipment_stainless_supplier                                          0.000000
# 58_cspmidcbf_markings_packaging_labelled                                           0.000000
# 62_steel_metallic_metal_materials                                                  0.000000
# 64_pipe_process_vrollers_inspection                                                0.000000
# 67_expenses_expense_supplier_costs                                                 0.000000
# 68_pipe_tests_test_specimen                                                        0.106608
#
#                                                   positively                                        \
# 6_warranties_warranty_warrants_repair                                                     0.000000
# 11_mixture_density_mixing_cement                                                          0.000000
# 21_tooling_tools_equipment_components                                                     0.000000
# 24_cspmidcbf_cspmidlmc_faults_maintenance                                                 0.000000
# 28_cspmidcbf_cspmidlmcprovided_phasebinned_phase                                          0.111937
# 33_hardness_steel_alloys_iron                                                             0.000000
# 50_criteria_fat_equipment_procedure                                                       0.271164
# 57_nameplate_equipment_stainless_supplier                                                 0.000000
# 58_cspmidcbf_markings_packaging_labelled                                                  0.000000
# 62_steel_metallic_metal_materials                                                         0.000000
# 64_pipe_process_vrollers_inspection                                                       0.000000
# 67_expenses_expense_supplier_costs                                                        0.000000
# 68_pipe_tests_test_specimen                                                               0.106608
#
#                                                   separates                                         \
# 6_warranties_warranty_warrants_repair                                                     0.000000
# 11_mixture_density_mixing_cement                                                          0.000000
# 21_tooling_tools_equipment_components                                                     0.000000
# 24_cspmidcbf_cspmidlmc_faults_maintenance                                                 0.000000
# 28_cspmidcbf_cspmidlmcprovided_phasebinned_phase                                          0.111937
# 33_hardness_steel_alloys_iron                                                             0.000000
# 50_criteria_fat_equipment_procedure                                                       0.135582
# 57_nameplate_equipment_stainless_supplier                                                 0.000000
# 58_cspmidcbf_markings_packaging_labelled                                                  0.000000
# 62_steel_metallic_metal_materials                                                         0.000000
# 64_pipe_process_vrollers_inspection                                                       0.000000
# 67_expenses_expense_supplier_costs                                                        0.000000
# 68_pipe_tests_test_specimen                                                               0.106608
#
#                                                   the                                          \
# 6_warranties_warranty_warrants_repair                                                0.000000
# 11_mixture_density_mixing_cement                                                     0.000000
# 21_tooling_tools_equipment_components                                                0.000000
# 24_cspmidcbf_cspmidlmc_faults_maintenance                                            0.000000
# 28_cspmidcbf_cspmidlmcprovided_phasebinned_phase                                     0.111937
# 33_hardness_steel_alloys_iron                                                        0.000000
# 50_criteria_fat_equipment_procedure                                                  0.000000
# 57_nameplate_equipment_stainless_supplier                                            0.000000
# 58_cspmidcbf_markings_packaging_labelled                                             0.000000
# 62_steel_metallic_metal_materials                                                    0.000000
# 64_pipe_process_vrollers_inspection                                                  0.000000
# 67_expenses_expense_supplier_costs                                                   0.000000
# 68_pipe_tests_test_specimen                                                          0.106608
#
#                                                   grades
# 6_warranties_warranty_warrants_repair                                                         0.0
# 11_mixture_density_mixing_cement                                                              0.0
# 21_tooling_tools_equipment_components                                                         0.0
# 24_cspmidcbf_cspmidlmc_faults_maintenance                                                     0.0
# 28_cspmidcbf_cspmidlmcprovided_phasebinned_phase                                              0.0
# 33_hardness_steel_alloys_iron                                                                 0.0
# 50_criteria_fat_equipment_procedure                                                           0.0
# 57_nameplate_equipment_stainless_supplier                                                     0.0
# 58_cspmidcbf_markings_packaging_labelled                                                      0.0
# 62_steel_metallic_metal_materials                                                             0.0
# 64_pipe_process_vrollers_inspection                                                           0.0
# 67_expenses_expense_supplier_costs                                                            0.0
# 68_pipe_tests_test_specimen                                                                   0.0
#
# [13 rows x 42 columns]

# %%
topic_model.visualize_distribution(topic_distr[3])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="096abe57-d187-43c4-8c52-33f5d687dcae" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("096abe57-d187-43c4-8c52-33f5d687dcae")) {                    Plotly.newPlot(                        "096abe57-d187-43c4-8c52-33f5d687dcae",                        [{"marker":{"color":"#C8D2D7","line":{"color":"#6E8484","width":1}},"orientation":"h","x":[0.05146503025234224,0.036987091211786616,0.040889813125599514,0.2519710433236757,0.04128955992436666,0.08892176782259427,0.1965738557118145,0.03782145951957544,0.04695740307169577,0.0467878686012395,0.036988950652315736,0.040029798133915835,0.08331635864907824],"y":["\u003cb\u003eTopic 6\u003c\u002fb\u003e: warranties_warranty_warr...","\u003cb\u003eTopic 11\u003c\u002fb\u003e: mixture_density_mixing_...","\u003cb\u003eTopic 21\u003c\u002fb\u003e: tooling_tools_equipment...","\u003cb\u003eTopic 24\u003c\u002fb\u003e: cspmidcbf_cspmidlmc_fau...","\u003cb\u003eTopic 28\u003c\u002fb\u003e: cspmidcbf_cspmidlmcprov...","\u003cb\u003eTopic 33\u003c\u002fb\u003e: hardness_steel_alloys_i...","\u003cb\u003eTopic 50\u003c\u002fb\u003e: criteria_fat_equipment_...","\u003cb\u003eTopic 57\u003c\u002fb\u003e: nameplate_equipment_sta...","\u003cb\u003eTopic 58\u003c\u002fb\u003e: cspmidcbf_markings_pack...","\u003cb\u003eTopic 62\u003c\u002fb\u003e: steel_metallic_metal_ma...","\u003cb\u003eTopic 64\u003c\u002fb\u003e: pipe_process_vrollers_i...","\u003cb\u003eTopic 67\u003c\u002fb\u003e: expenses_expense_suppli...","\u003cb\u003eTopic 68\u003c\u002fb\u003e: pipe_tests_test_specime..."],"type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"hist ...

# %%
# Preprocess your test data (test_requs) if necessary


# Use the trained BERTopic model for inference
test_topic_assignments, _ = topic_model.transform(test_requs)

# Retrieve the topic labels mapping from the BERTopic model
topic_labels = topic_model.get_topic_info()

# Create a dictionary to map numeric topic IDs to text labels
topic_id_to_label = {id: label for id, label in zip(topic_labels["Topic"], topic_labels["Name"])}

# Print the actual text and the assigned topic labels as text labels
for i, (test_doc, test_doc_topic) in enumerate(zip(test_requs, test_topic_assignments)):
    print(f"Test Document {i}:")
    print("Text:", test_doc)
    print("Assigned Topic:", topic_id_to_label[test_doc_topic])
    print("\n")
# Out:
# Test Document 0:
# Text:  We shall provide engineering drawings in AutoCAD format computer software and documentation user manual maintenance manual preventive maintenance schedule bill of material configuration and setup information safety information and troubleshooting information and all documentation shall be provided on three CDs and printed upon request from the customer.
# Assigned Topic: 30_requirements_specifications_documents_manuals
#
#
# Test Document 1:
# Text: If the purchaser requires soundness tests to be performed, it shall be so stated in the purchase agreement, and the method and soundness requirements shall be detailed
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 2:
# Text: CSP_Mid.CBF shall require less than 18 Direct Maintenance Hours (DMH) per month at the Organizational Level (O-Level).
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 3:
# Text: Steel cast in ingots or strand cast is permissible. When steels of different grades are sequentially strand cast, identifi_x0002_cation of the resultant transition material is required. The producer shall remove the transition material by any estab_x0002_lished procedure that positively separates the grades.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 4:
# Text: CSP_Mid.CBF shall, for each visibility, calculate and output, in the format specified in the MID SDP to CSP Interface Control Document [300-000000-002], its Time Centroid Index (TCI), which is the normalized and unit-less flagging-weighted effective time centroid of the visibility's integration time.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 5:
# Text: Stands shall be placed at each inlet to a concrete irrigation pipe system and at such other points as required. All stands shall be installed on a base adequate to support the stand and to prevent undue movement or stress on the pipeline. All stands shall serve as vents in addition to their other functions as follows
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 6:
# Text: National Electric Code (NEC).
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 7:
# Text: wiring identification: (laser brand or thermal transfer only) ¯ all wiring will have identification markings as follows for ease of troubleshooting:  alternate methods of wire marking may be acceptable but must include detailed wiring
# schematics of origination and termination points between must show all connection points
# between terminal blocks, plugs, cabinet interfaces, etc. wiring identification must be
# maintained from orientation to termination without change (alternate method must be
# approved by pinc tef department).
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 8:
# Text: CSP_Mid.CBF racks shall have a safety earth connection point with a connection resistance of less than 0.1 Ohm as per
# the latest approved version of the MID CSP to INFRA ICD.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 9:
# Text: When commanded, CSP_Mid.CBF shall apply a CSP_Mid.LMC-provided frequency-dependent (with at least 1 MHz resolution), per-antenna, per-beam polarization calibration corrections, prior to VLBI beamforming.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 10:
# Text: there must be a manual function to test all station lights (stack lights, good bad lights, etc.) at one time to detect for defective bulbs.
# Assigned Topic: 5_deactivation_hmis_hmi_timers
#
#
# Test Document 11:
# Text:  Each bucker station paddle shall lower the pipe onto the bucker station vrollers.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 12:
# Text: A Re-Direct Roller System shall be provided at the front of the Creel to re-direct the yarn from the width of the Creel to the width of the production line as specified in paragraph 9.1.7.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 13:
# Text: CSP_Mid.CBF equipment hardware failures and software errors shall not create hazardous conditions in interfacing elements and sub-elements.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 14:
# Text: For castings of such size or shape that do not permit Brinell testing with the standard 3000 kgf load, the 500 kgf may be employed, the hardness number being reported as HB 10/500/15. In very unusual cases where it is impossible to use the Brinell method, the Rockwell test may be substituted, using Test Methods E18 with an appropriate Rockwell scale. Con_x0002_versions of hardness values from one method to another according to Hardness Conversion Tables E140, which does not specifically cover cast irons, are approximate only and, therefore, are generally inadvisable
# Assigned Topic: 0_retests_testing_retest_test
#
#
# Test Document 15:
# Text:  Each box end threading inspection station shall have a paddle lift.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 16:
# Text: When commanded, CSP_Mid.CBF shall perform automatic uniformly-distributed statistical temporal load balancing of packets present on the I.S1M.SDP_CSP.001 interface, with peak packet rate at any given time, averaged over the transmission time of any 15 time-contiguous packets, less than 125% of the packet rate averaged over at least 10 seconds.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 17:
# Text: precision work requires the operator to rest arms, elbows and or hands on surfaces these surfaces require a minimum thickness of 0.25î padding.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 18:
# Text:  Each station shall have an emergency stop button with a safety circuit.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 19:
# Text: Because of the complexity of these factors in influ_x0002_encing the properties of the final product, no precise quantita_x0002_tive relationship can be stated between the properties of the iron in various locations of the same casting or between the properties of a casting and those of a test specimen cast from the same iron. When such a relationship is important and must be known for a specific application, it may be determined by appropriate experimentation
# Assigned Topic: 0_retests_testing_retest_test
#
#
# Test Document 20:
# Text: It shall be possible to locate two Dishes with centre-to-centre spacing of 30 meters without any possibility of collision.
# Assigned Topic: 3_dish_pointing_ranging_tracking
#
#
# Test Document 21:
# Text:  Each pipe shall gravity roll to the fixed stop at the lifting station.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 22:
# Text: A Yarn Comb for (220) ends shall be provided for each of the two (2) PAN sheets.
# Assigned Topic: 54_yarn_bobbins_bobbin_combs
#
#
# Test Document 23:
# Text:  Each box end end blast station shall have a fixed pipe stop.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 24:
# Text: supplier must ensure all equipment meets osha and dhec regulatory requirements.
# Assigned Topic: 6_safety_equipment_personnel_guards
#
#
# Test Document 25:
# Text: At the request of the purchaser, analyses of two pipes from each lot (see 20.1) shall be made by the manufacturer from the finished pipe. The results of these analyses shall be reported to the purchaser or the purchaser’s representative and shall conform to the requirements specified in Section 7
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 26:
# Text:  Each pipe shall be lifted off of the fixed pipe stop and lowered onto the pin end dope and threading protector station vrollers by paddle lift.
# Assigned Topic: 2_pipe_threaded_adjustable_adjustment
#
#
# Test Document 27:
# Text: For any Band and for each Pulsar Search beam, CSP_Mid.CBF shall form 4096 equally-spaced and critically-sampled channels across the Search Window channelized bandwidth.
# Assigned Topic: 13_mhz_pulsar_beamforming_frequency
#
#
# Test Document 28:
# Text: The noise diode switching waveform shall be synchronised to the 1PPS time reference with an accuracy of 50ns (TBC).
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 29:
# Text: When castings are specified for government procurement, the location of the permanent markings specified in 15.1, as well as any special marking for mechanical or physical properties (either permanent or temporary), shall be as indicated on the government drawings or sketches.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 30:
# Text: All individual components, skid assemblies, and modules shall be furnished with lifting lugs Each shall be installed on crush plates Components longer than 10í-0î shall be furnished with two tailing lugs of the same design as the lifting lugs All lifting lugs shall be positioned to allow a balanced lift Lifting lug placement shall not allow the equipment to be stressed or deformed while being lifted.
# Assigned Topic: 22_welded_structural_frame_frames
#
#
# Test Document 31:
# Text: Subject to fundamental limitations from DSH sample clock frequency offsets, correlator integration time, and filter Nyquist zones, CSP_Mid.CBF shall confine RFI to its on-sky spectral occupancy by:
# 1. achieving at least 30 dB attenuation over and above stopband attenuation of (aliased) RFI not native to its Frequency Slice or Search Window, in cross-correlation visibilities,
# 2. not limiting further attenuation of such (aliased RFI) in cross-correlation visibilities for increased frequency offsets and/or integration times and,
# 3. ensuring such (aliased) RFI does not add coherently in any tied-array (beamformer) outputs.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 32:
# Text:  The vrollers shall rise and the radial rollers shall lower to transfer the pipe out of the pin end end blast station.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 33:
# Text: Each SKA1_Mid dish shall provide switchable, wideband calibration signals that are injected into both polarisation channels (i.e. one signal into both channels), at the earliest possible point preceding the LNA.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 34:
# Text: The Dish shall be able to achieve maximum velocity and acceleration rates in both azimuth and elevation axes simultaneously.
# Assigned Topic: 3_dish_pointing_ranging_tracking
#
#
# Test Document 35:
# Text: tooling or fixtures switched during change over shall attach to a sub-plate in accordance with ësingle minute exchange dieí (smed) design philosophies.
# Assigned Topic: 24_tooling_tools_equipment_features
#
#
# Test Document 36:
# Text:  The bucker station vrollers shall lower and allow each pipe to gravity roll towards the next station.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 37:
# Text: When commanded for each subarray, CSP_Mid shall capture into a Transient buffer selectable 2-bit, 4-bit, or 8-bit quantized dual- polarization voltage data selectable from one or both of the Search Windows, post-delay and phase corrected.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 38:
# Text: The term “commercial castings” does not cover castings requiring special fixtures for gaging, or finishing castings by grinding to special tolerance gages beyond the normal requirements as listed in Table S51.1.
# Assigned Topic: 0_retests_testing_retest_test
#
#
# Test Document 39:
# Text: The DSH shall persist the in-maintenance status of items in the DSH structure of reporting beyond the TM-DSH communication session and beyond the powered up state of the DSH.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 40:
# Text:  Equipment shall be designed to CSA Z432 04 standards.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 41:
# Text:  Each threading line shall have two lifting station.
# Assigned Topic: 1_threading_line_dials_inspection
#
#
# Test Document 42:
# Text: DSH shall provide an environmental protected enclosure inside the Pedestal Shielded Compartment and maintain the internal conditions as defined by the DSH Consortium Non-Operating Conditions for equipment located inside the PSC for SADT equipment located inside the pedestal while being subjected to Survival Conditions.
# Assigned Topic: 14_dsh_enclosure_pedestal_pedestals
#
#
# Test Document 43:
# Text: control panels will be easily accessible.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 44:
# Text: Visibilities produced by CSP_Mid.CBF shall have an amplitude response, after application of Mid.CBF per-channel gain factors, that varies by at most +/-0.01 dB across the processed bandwidth for any Band. Note: applies to both zoom and non- zoom visibilities.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 45:
# Text: whenever possible form features shall be used to hold product components in grippers clamping forces shall not mark, deform or damage the product in any way.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 46:
# Text: CSP_Mid.CBF equipment items identified in the SKA Logistics Analysis and Configuration Item Plan as needing individual characterisation shall be marked with a label displaying a unique Serial Number and Part Number. The label should normally be in an easily visible location but may also include embedded identification for items such as embedded firmware/software.
# Assigned Topic: 31_cspmidcbf_midcbf_labelling_packaging
#
#
# Test Document 47:
# Text: Install construction joints where concrete placement operations are interrupted for
# more than 30 minutes. Place a header to create a vertical face that is perpendicular to the
# centerline, and use tie bars as needed.
# Assigned Topic: 22_welded_structural_frame_frames
#
#
# Test Document 48:
# Text: all robots must have a teach pendant with english interface the teach pendant must have a station e-stop for safety.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 49:
# Text: External conductive parts shall be grounded in compliance to: South Africa:
# National Building Regulations and Building Standards Act, 1977 Occupational Health and Safety act, 1993
# SANS 10313
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 50:
# Text:  Each pipe shall gravity roll to the fixed pipe stop at the pin end end blast station.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 51:
# Text: Castings shall have gates and risers removed in such a manner that no riser or gate stub projects or a depression is made beyond or below the casting design contour in an amount that would exceed the values given in Table S52.1.
# Assigned Topic: 0_retests_testing_retest_test
#
#
# Test Document 52:
# Text:  The adjustable pipe stop design shall have allow a straightforward integration for automatic adjustment with back and forth pipe stop articulation.
# Assigned Topic: 2_pipe_threaded_adjustable_adjustment
#
#
# Test Document 53:
# Text: Over all bands and the full elevation range and under Precision and Standard Operating Conditions, after correcting for pointing errors, the on-diagonal Mueller matrix patterns shall not vary by more than 5% relative to the peak gain for any rotation around the optical axis of up to 1°, down to the -20 dB contour (TBC).
# Assigned Topic: 19_precision_pointing_circle_perreceptor
#
#
# Test Document 54:
# Text:  A control cabinet with a main 480VAC flange mounted disconnect shall be provided and should be located near the threading line equipment.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 55:
# Text: When commanded, for any subarray and any Band, CSP_Mid.CBF shall track delay and phase at a
# rate corresponding to 20 times sidereal tracking, while meeting all signal processing requirements including but not limited to accuracy, precision, efficiency, and performance of correlation and tied-array beamforming.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 56:
# Text: For each subarray, CSP_Mid.CBF shall assume there is 1 subarray phase center (a.k.a. delay center or topocenter), used for all TM or LMC-provided delay and phase tracking models, which is fixed for the duration of the subarray observation, and is located within 10 km of the center of the smallest circle that encompasses all receptors in the subarray. Note: does not apply to VLBI subarrays.
# Assigned Topic: 7_ghz_rf_hz_receptor
#
#
# Test Document 57:
# Text: The manufacturer shall furnish an analysis of each shipment showing the silicon content and, when required, such of the other elements specified in Table 1
# Assigned Topic: 30_requirements_specifications_documents_manuals
#
#
# Test Document 58:
# Text: Where the hydrostatic test and the nondestructive electric test are omitted and the lengths marked with the letters “NH,” the certification, where required, shall clearly state “Not Hydrostatically Tested,” and the letters “NH” shall be ap_x0002_pended to the product specification number and material grade shown on the certification
# Assigned Topic: 0_retests_testing_retest_test
#
#
# Test Document 59:
# Text: The values stated in either SI units or inch-pound units are to be regarded separately as standard. The values stated in each system may not be exact equivalents; therefore, each system shall be used independently of the other. Combining values from the two systems may result in nonconformance with the standard
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 60:
# Text:  Each paddle lift shall lift pipe off of the adjustable pipe stop and the pipe shall roll against the stop on the paddle lift.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 61:
# Text: Correct surface irregularities to prevent the formation of depressions or water pockets. Compact
# topsoil lightly to ensure contact with the underlying soil and to create a uniform seedbed.
# Assigned Topic: 27_mixture_density_mixing_cement
#
#
# Test Document 62:
# Text: DSH shall control its consumption of power to a level requested by TM, with levels as defined in the TM_DSH ICD.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 63:
# Text:  The design of the vrollers shall contain many similar features of the vrollers Welded Tube uses in quench and temper with the exception of high temperature designs.
# Assigned Topic: 26_welded_tube_commissioning_equipment
#
#
# Test Document 64:
# Text:  The quench and temper material handling equipment is being manufactured to CSA Z432 04 and the threading equipment shall be manufactured the same way with incorporated Category Four safety requirements.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 65:
# Text: The Transient Buffer for CSP_Mid.CBF shall allow for a latency of up to 62 seconds from the Transient Epoch until the Transient Trigger from CSP_Mid.LMC is present on the CSP_Mid.LMC to CSP_Mid.CBF interface.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 66:
# Text: bowls should be constructed with backpressure relief where possible if parts in the bowl do not allow for this technique, a set of high low sensors located in the discharge track should be used.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 67:
# Text: CSP_Mid.CBF shall enter the Low Power Mode on startup and remain in Low Power mode until commanded otherwise.
# Assigned Topic: 12_cspmidcbf_cspmidlmc_faults_maintenance
#
#
# Test Document 68:
# Text: The sensitivity of a SKA1_Mid dish shall not be less than the following compared to that which is specified in R.M.P.1, at any pointing angle over the elevation range from zenith down to 30° above the horizon, under precision and standard operating conditions, and when calculated as an average over any 1 MHz interval over the specified frequency range in both polarization channels: 75% for SPF band 5a.
# Assigned Topic: 33_ska1sysreq2180_ska1mid_sensitivity_polarization
#
#
# Test Document 69:
# Text: The 'LanguagePreferredList' element contains one or more 'LanguagePreferredComponentDef' elements.
# Assigned Topic: 59_languagepreferredcomponentdef_unicode_unicodeset_languagepreferredlist
#
#
# Test Document 70:
# Text: Packaged LRU's and SRU's shall have the following markings securely attached on the outside of the packaging container:
# a) Mode of transport "careful transportation"
# b) "This side up" label
# c) "Fork lift here" label, where applicable
# d) Centre of gravity marking, where applicable
# e) Packaged Item Identification plate, with identification data completed, as specified in
# R.D.RPA.1
# f) Where applicable, tamper proof labels for "wrong way up" and "excessive acceleration" g) ESD warnings where applicable
# Assigned Topic: 55_packaging_srus_packaged_carrying
#
#
# Test Document 71:
# Text:  Powered radial rollers shall rise and the vrollers shall lower.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 72:
# Text:  You can be sure that the system shall remain within your original specification and each step of the poject from design reviews to project questions will be documented for verification.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 73:
# Text: CSP_Mid.CBF LRU equipment with a weight of more than 40 kg shall have an integral lifting arrangement to allow mechanical assisted lifting.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 74:
# Text: The tension test specimens shall be cast to the form and dimensions shown in Fig. 1 or Fig. 2, in the same kind of molding material used for the production castings. At least three such specimens shall be cast from a representative ladle of iron either from each batch-melted heat or, in continuous melting, from each 4 h pour period during which the purchas_x0002_er’s castings were poured, or as otherwise agreed upon between manufacturer and purchaser
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 75:
# Text: All bolts, nuts, washers and other attachment hardware shall be zinc plated carbon steel.
# Assigned Topic: 9_painted_paint_painting_coat
#
#
# Test Document 76:
# Text: When commanded, CSP_Mid.CBF shall process up to 1400 MHz per polarization of contiguous RF (sky) data within the Band 3 band of interest.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 77:
# Text: When commanded and with the CSP_Mid.CBF Administrative Mode set to OFFLINE, CSP_Mid.CBF shall isolate 95% of all failures down to a LRU level.
# Assigned Topic: 12_cspmidcbf_cspmidlmc_faults_maintenance
#
#
# Test Document 78:
# Text:
# When commanded, CSP_Mid.CBF shall process up to 700 MHz per polarization of contiguous RF (sky) data within the Band 1 band of interest.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 79:
# Text: CSP_Mid.CBF racks shall provide at least one ESD grounding connection point in accordance with the latest approved version of the MID CSP to INFRA ICD.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 80:
# Text: The DSH, when in the operating state, shall continuously send to TM, estimated Az/El pointing positions, with a resolution of up to 100ms, corrected for locally applied corrections.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 81:
# Text: Over the full accessible elevation range, under Precision and Standard Operating Conditions, Antenna efficiency in two orthogonal polarizations shall exceed a line interpolated linearly between:
# 60% at 350 MHz 78% at 600 MHz 78% at 8000 MHz 70% at 15 GHz 65% at 20 GHz
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 82:
# Text:  The commercial software provided with the project shall not be warrantied by the seller and the software manufacturers warranty shall apply.
# Assigned Topic: 18_warranties_warranty_warrants_repair
#
#
# Test Document 83:
# Text:  Welded Tube shall be responsible for all power air and other utility drops to the machines while the power and other utilities will be brought to AEC designated connection points on the machine.
# Assigned Topic: 26_welded_tube_commissioning_equipment
#
#
# Test Document 84:
# Text: When commanded, CSP_Mid.CBF shall apply CSP_Mid.LMC- provided polarization calibration corrections to each VLBI beam individually, to at least the Frequency Slice frequency resolution (224 MHz), before output.
# Assigned Topic: 16_beamchannels_beamchannel_mhz_rfi
#
#
# Test Document 85:
# Text: The power spectral density of the switchable calibration signal shall be equivalent to 5 - 13% of Tsys (range inclusive), averaged over any 1 MHz bandwidth across the specified frequency range and with Tsys computed for Cold sky at the lowest specified elevation angle.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 86:
# Text: The CSP_Mid.CBF Network Time Protocol (NTP) interface to SADT shall be compliant with the Interface
# ID I.S1M.SADT_CSP.002 section of the MID SADT to CSP ICD.
# Assigned Topic: 21_cspmidcbf_csp_icd_sdp
#
#
# Test Document 87:
# Text: Supplierís purchased components may be supplied with their factory coatings if suitable for high temperature environment of maximum 150∫F.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 88:
# Text: R.D.RM.9
# All Cables/Harnesses and their connectors shall be labelled to allow identification while the Cables/Harnesses is installed.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 89:
# Text: The Purchaser shall furnish the following: Lighting for operation maintenance.
# Assigned Topic: 8_components_supplier_equipment_yarn
#
#
# Test Document 90:
# Text: The project shall include a Description of the Project.
# Assigned Topic: 25_planning_scheduled_meetings_schedule
#
#
# Test Document 91:
# Text: When producing Pulsar Search beams, for any Band, the CSP_Mid.CBF Search Window beamforming bandwidth (before channelization) shall have spectral confusion of no more than -40 dB in amplitude and 0.01 radians in phase compared to an ideal beamformer provided with the same inputs.
# Assigned Topic: 13_mhz_pulsar_beamforming_frequency
#
#
# Test Document 92:
# Text: freestanding bowl support tables should have heavy-duty adjustable mounting feet for final alignment at set up.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 93:
# Text: Each VLBI beam-channel produced by CSP_Mid.CBF shall have a temporal impulse response that is no worse (i.e., temporally broader) than the inverse Fourier Transform of that beam- channel's frequency response.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 94:
# Text: flexibility for new routings parts: new part numbers can be introduced with a specific routing and individual process parameters by a database system.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 95:
# Text: DSH equipment, while in its storage packaging, shall withstand, and shall operate to specification as defined herein after exposure to, the storage environmental conditions as defined in “Class 1.1: Weather protected, partly temperature-controlled storage locations” of the ETSI EN 300 019-1-1 standard.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 96:
# Text: machine will be equipped with a main air valve with soft start when the machine is powered on and rapidly exhaust all line pressure when the machine is powered off.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 97:
# Text: vents and dirt discharge ports are required to eliminate dirt and foreign particles from reaching escapement.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 98:
# Text: When commanded, CSP_Mid.CBF shall process up to a total of 3900 MHz per polarization within the Band 5a band of interest, consisting of CSP_Mid.LMC-defined portions, in whole or in part, of either or both 5a1 and 5a2 bands of interest.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 99:
# Text: CSP_Mid.CBF shall operate in compliance with the SKA1 Power Quality Standard Specification [SKA-TEL-SKO-00000293] in accordance with the latest approved version of the MID CSP to INFRA Interface Control Document [300-000000-020].
# Assigned Topic: 15_iec_cspmidcbf_csp_cpf
#
#
# Test Document 100:
# Text: accessibility for manual removal of jammed parts shall be provided to improve oee.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 101:
# Text: when the station is in manual mode or the robot is in teach mode, the robot shall move at only 1.00% of full velocity with reduced torque.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 102:
# Text: The total per-receptor RMS Tracking Stability Error under Precision Operating Conditions, maintained while tracking a celestial target anywhere within the full performance pointing range over a time interval of 1000 seconds, shall be <= 2.3 arcsec RMS.
# Assigned Topic: 19_precision_pointing_circle_perreceptor
#
#
# Test Document 103:
# Text: The packaging of all line replaceable units (LRUs) shall be labelled, with the following information:
# - Item Name (from Config Management System)
# - Item Part Number and Version (from Config Management System)
# - Item serial number (where applicable) (shall be able to update this for the relevant unit)
# - Packaged weight
# - Container stackability (where applicable)
# - Preservation date (where applicable)
# - Shelf life (where applicable)
# - Electronically scannable label (Bar Code), containing all the above information.
# Assigned Topic: 46_markings_marking_labelled_packaging
#
#
# Test Document 104:
# Text:  If no pipe is present at the end of the pin end end blast station then the pipe is lifted off of the pipe stop and lowered onto the pin end end blast station vrollers.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 105:
# Text: The DSH shall be fully functional when operated under the Precision, Standard, Degraded and Extreme Operating Conditions throughout the required Deployed Lifetime.
# Any DSH equipment located at weather protected locations provided by other Elements shall be subjected to the conditions defined in the relevant ICD's.
# Assigned Topic: 14_dsh_enclosure_pedestal_pedestals
#
#
# Test Document 106:
# Text: all work stations will be equipped with adequate lighting for operators a minimum of 2 lights (4 ft florescent lights) is requested per workstation unless limited by workstation design lux requirements should be considered depending on the type of activity performed at stations.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 107:
# Text: if there is a special condition to move a device in manual, i.e. a cylinder must be extended in order to move a second cylinder, there must be an error message displayed in the event the second cylinder is not actuated in the correct sequence.
# Assigned Topic: 5_deactivation_hmis_hmi_timers
#
#
# Test Document 108:
# Text: Surface imperfections that penetrate more than 121⁄2 % of the nominal wall thickness or encroach on the minimum wall thickness shall be considered defects. Pipe with such defects shall be given one of the following dispositions:
# Assigned Topic: 20_pipe_tests_bend_test
#
#
# Test Document 109:
# Text:  The project warranty shall cover software.
# Assigned Topic: 18_warranties_warranty_warrants_repair
#
#
# Test Document 110:
# Text: The TM shall configure the DSH parameters as required for the observation. The TM will do this by passing parameters to DSH via a Capability request.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 111:
# Text: Sufficient material shall be removed from the cast surface to ensure that the measured surface is representative
# Assigned Topic: 0_retests_testing_retest_test
#
#
# Test Document 112:
# Text:  If the automatic stop adjustment option is chosen then the electric cylinder shall automatically position the adjustable pipe stop to the proper position for the given outer diameter recipe and if it isn't chosen then it shall be manually positioned by the operator.
# Assigned Topic: 2_pipe_threaded_adjustable_adjustment
#
#
# Test Document 113:
# Text: All Engineering documents and data listed in the Vendor Data Requirements Form including but not limited to the following: Component Drawings.
# Assigned Topic: 30_requirements_specifications_documents_manuals
#
#
# Test Document 114:
# Text:  Each pipe shall gravity roll to the fixed pipe stop at the pin end dope and threading protector station.
# Assigned Topic: 2_pipe_threaded_adjustable_adjustment
#
#
# Test Document 115:
# Text: DSH shall provide the routing and mounting of fibres and power cables, from the INFRA point of supply, of the SADT equipment mounted to DSH with the mechanical characteristics as defined in 300-000000-026 (SADT-DSH ICD).
# Assigned Topic: 14_dsh_enclosure_pedestal_pedestals
#
#
# Test Document 116:
# Text: workstations will be designed for sitting operators using an eurgo style sit semi-stand seat angled footrests will be incorporated into all manual workstations the workstation work surface shall be 37 inches above the floor for all operations unless approved by pierburg inc. .
# Assigned Topic: 39_clearance_workbench_workstations_worker
#
#
# Test Document 117:
# Text:  Each pipe shall be lifted onto the next transfer table.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 118:
# Text: Visibilities produced by CSP_Mid.CBF shall have a latency of no more than 1 second or three correlator integration periods, whichever is longer, after receipt of streaming data
# from SKA1_Mid receptors at the I.S1M.SADT_CSP.009 (DSH) ingress boundary, until present at the I.S1M.SADT_CSP.005 egress boundary. Note: applies to zoom, non-zoom, and visibilities produced in support of VLBI.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 119:
# Text: The counters in this subclause are instantiated for each port on which the Stream identification function (6.2) is configured. They are indexed by port number. Encoded as unsigned integers, they shall be 64 bits in length to ensure against excessively short wrap times when used on links on which transmission rate exceeds 650 000 000 bits per second.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 120:
# Text: CSP_Mid.CBF rack and LRU equipment shall be safety certified to SANS 60950-1:2014 or equivalent in accordance with the latest approved version of the MID CSP to INFRA ICD.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 121:
# Text: The tensile strength shall be the maximum load carried by the specimen during the test divided by the original cross-sectional area of the gage length, as found in accordance with 7.3.2. It shall be reported to the nearest 100 psi [MPa].
# Assigned Topic: 0_retests_testing_retest_test
#
#
# Test Document 122:
# Text: When commanded, CSP_Mid.CBF shall configure its processing resources such that:
# 1. Sampled signals for any Band are divided into multiple identical Frequency Slices located within the processed bandwidth of any Band, and with Frequency Slice processed bandwidth independent of the Band.
# 2. Any Frequency Slice -- or, for Pulsar Search, Search Window -- from any Band for all SKA1_Mid receptors, is processed in one or more Frequency Slice Processors, each of which may be configured for any one of the following "Function Modes" at any one time:
# 1. Correlation, for up to at least 16 sub-arrays independently, each sub-array producing zoom or non-zoom visibilities,
# 2. Pulsar Timing beamforming, for up to at least 16 sub-arrays independently, internally producing Pulsar Timing beams for subsequent Pulsar Timing processing.
# 3. Pulsar Search beamforming, for up to at least 16 sub-arrays independently, internally producing Pulsar Search beams for subsequent Pulsar Search processing or,
# 4. VLBI, for up to at least 4 VLBI sub-arrays independently, concurrently producing VLBI beams and visibilities in support of VLBI.
# Assigned Topic: 13_mhz_pulsar_beamforming_frequency
#
#
# Test Document 123:
# Text: CSP_Mid.CBF equipment shall be compliant with environmental, ecological, safety, political and social legislation with regard to recycling and decomposition.
# Assigned Topic: 31_cspmidcbf_midcbf_labelling_packaging
#
#
# Test Document 124:
# Text:
# Under Precision and Standard Operating Conditions the dish element shall limit un-modelled beam rotation on the sky to no more than 1°.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 125:
# Text: four pallet before and after all manual stations.
# Assigned Topic: 64_stations_station_pallet_project
#
#
# Test Document 126:
# Text:  The vrollers of the box end pipe dope station shall then return to the up position and shall be prepared to accept the next pipe.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 127:
# Text: A 200 response shall be provided in a success case. The payload shall contain information for the requested Device.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 128:
# Text:
# The Dish shall have a continuous accessible azimuth range from -270° to +270° inclusive of pointing model corrections, measured relative to true North defined as 0° and with East defined as +90°.
# Assigned Topic: 3_dish_pointing_ranging_tracking
#
#
# Test Document 129:
# Text: CSP_Mid.CBF LRUs weighing more than 23 kg shall have a Weight Warning label.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 130:
# Text: all data is stored in a database on a pc-basis data shall be imported automatically into an excel spreadsheet type format file (file name shall be by date: yy-mm-dd xls) from the database system and have the capability to pulled easily from the data based onto a cd burn system or tape back up system for supplied database of the integrator pulling data shall not impact the availability performance of the assembly operations or stations status lighting at every station must be mounted for good visibility (top down: red-yellow-green).
# Assigned Topic: 30_requirements_specifications_documents_manuals
#
#
# Test Document 131:
# Text: When commanded, CSP_Mid.CBF shall, within each Frequency Slice Processor configured for VLBI, and for all SKA1_Mid receptors within each VLBI subarray independently and simultaneously with VLBI beamforming, produce and deliver to the SDP up to 800 to 1024 VLBI visibility channels per polarization for each of 4 polarizations, linearly spaced across the Frequency Slice bandwidth, using the same calibration and delay models as for one select VLBI beam.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 132:
# Text: While the values for yield point and yield strength are not identical, they are sufficiently close for most applications of ferritic malleable irons to be used interchangeably. They may be determined by any of the approved techniques described in the paragraphs on Determination of Yield Strength and Yield Point of Test Methods E8/E8M. If determined as yield strength, that stress producing an extension under load of 0.01 in. [0.25 mm] over the 2 in. [50 mm] gage length (for example, 0.5 % extension) or an offset of 0.2 % shall be taken as the yield stress, which shall be converted to yield strength by dividing by the original cross-sectional area of the gage length found in accordance with 7.3.2. It shall be reported to the nearest 100 psi [MPa]. In referee work, yield strength shall be determined as the stress that produces an extension under load of 0.5 % of the gage length.
# Assigned Topic: 0_retests_testing_retest_test
#
#
# Test Document 133:
# Text: Where the Origin Cloud supports OCF Device to Cloud Services a request to this API may be triggered by reception of an UPDATE to a URI exposed by a Link in the OCF Cloud Resource Directory from an OCF Client.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 134:
# Text: Under precision and standard operating conditions the passband gain of each SKA1_Mid dish, within the -3 dB contour of the co-polarized Jones pattern, shall not deviate by more than the following from a linear fit over fractional bandwidths of 0.1%:
# 1) 0.16% over SPF band 1
# 2) 0.21% over SPF band 2
# 3) 0.25% over SPF band 3
# 4) 0.29% over SPF band 4
# 5) 0.34% over SPF band 5a
# 6) 0.41% over SPF band 5b
# Assigned Topic: 33_ska1sysreq2180_ska1mid_sensitivity_polarization
#
#
# Test Document 135:
# Text:  The software warranty shall not apply to any software that has been modified except by the seller and the warranty shall not apply to any software commercial or custom on a computer that has been modified with either hardware or software upgrade or replacement.
# Assigned Topic: 18_warranties_warranty_warrants_repair
#
#
# Test Document 136:
# Text: Bearings shall be fully-self aligning and shall be equipped with single ñlip contact seals to exclude dust and moisture from internal parts of the bearing.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 137:
# Text: Concrete pipelines shall not be installed on sites where the sulfate salt concentration exceeds 1.0% as water soluble sulfate in soil samples, or 4000 parts per million (ppm) sulfate in groundwater samples. Concrete pipe shall be made with cement of the type shown for the following conditions
# Assigned Topic: 42_pipelines_pipeline_pipe_concrete
#
#
# Test Document 138:
# Text: CSP_Mid.CBF equipment that would otherwise present a safety hazard when subjected to an unplanned loss of main electrical power or main control function, shall enter a designated fail safe state.
# Assigned Topic: 12_cspmidcbf_cspmidlmc_faults_maintenance
#
#
# Test Document 139:
# Text: part failures at processing stations that require offline rework must be placed in a non-conforming material lock box or similar device after the first failure.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 140:
# Text: When commanded, CSP_Mid.CBF shall communicate
# to CSP_Mid.LMC all time-dependent receptor weights calculated and applied internally to any tied-array beam sum, with at least the temporal resolution of the currently configured
# subarray visibility integration time (or 1.4 seconds if none are currently being produced), and with the frequency resolution of the channelized bandwidth of each beam.
# Assigned Topic: 7_ghz_rf_hz_receptor
#
#
# Test Document 141:
# Text: Where the Origin Cloud supports OCF Device to Cloud Services this may be triggered by reception of a RETRIEVE to a URI exposed by a Link in the OCF Cloud Resource Directory from an OCF Client.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 142:
# Text:  Each pipe shall be automatically lifted to the CNC threading machine center by electric cylinder.
# Assigned Topic: 43_pipe_cnc_pipes_tube
#
#
# Test Document 143:
# Text: whenever possible the line should be designed to operate effective with 50% of the specified operators to support fluctuating production requirements.
# Assigned Topic: 1_threading_line_dials_inspection
#
#
# Test Document 144:
# Text: Furnace temperatures for heat treating shall be regulated by the use of pyrometers
# Assigned Topic: 0_retests_testing_retest_test
#
#
# Test Document 145:
# Text: transport pallet shall be used to transport the product pallet will not be used as fixtures for critical operations pierburg inc must approval deviations from this specification if pallet are used as fixtures then each measurement must have a capability (cpk) > 1.0.33 the measurement report has to be provided to pierburg inc. .
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 146:
# Text:  The project shall include a Sequence of Operations and the Sequence shall be identical for both threading lines.
# Assigned Topic: 1_threading_line_dials_inspection
#
#
# Test Document 147:
# Text:  The powered and self centering vrollers shall continue to transfer the pipe through the chuck and into the CNC machine.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 148:
# Text:  The risk to the project to you and to the AEC shall be assessed.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 149:
# Text: jog mode ñ this mode will pause the machine at each step in the program the operator will need to press a jog button on the operator panel to execute the active step and associated outputs, at which time the machine will proceed to the next step and wait again for the jog button to be pressed at any time, the operator should be able to make the machine continue running in automatic mode from jog mode without needing to bring the machine to home position first.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 150:
# Text: CSP_Mid.CBF shall provide all signal processing functions meeting requirements for SKA1_Mid receptor boresight pointing of 360 degrees in azimuth and down to at least 15 degrees elevation angle.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 151:
# Text: DSH shall report information in a hierarchical structure, including a product breakdown structure and a capability structure.
# Assigned Topic: 45_dsh_firmware_maintenance_diagnostics
#
#
# Test Document 152:
# Text: CSP_Mid.CBF equipment, while in its storage packaging, shall withstand, and shall operate to specification as defined
# herein after exposure to, the storage environmental conditions as defined in “Class 1.1: Weather protected, partly temperature- controlled storage locations” of the ETSI EN 300 019-1-1 standard and defined in BS EN IEC 60721-3-1.
#  Climatic Conditions: 1K3
#  Biological Conditions: 1B2
#  Chemical conditions: 1C2
#  Dust and Sand conditions: 1S2
#  Shock & Vibration Conditions: 1M2
# Assigned Topic: 31_cspmidcbf_midcbf_labelling_packaging
#
#
# Test Document 153:
# Text:  Each threading line shall have a box end high speed threading station.
# Assigned Topic: 1_threading_line_dials_inspection
#
#
# Test Document 154:
# Text: part failures at testing stations must be placed by an automatic device in a non-conforming material lock box or similar device after the third consecutive failure.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 155:
# Text: The test methods described in this section are not necessarily capable of inspecting the end portion of pipes, a condition referred to as “end effect.” The length of such end effect shall be determined by the manufacturer and, when specified in the purchase order, reported to the purchaser.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 156:
# Text: CSP_Mid.CBF equipment weighing more than 23 kg shall have lifting provisions to allow team lifting and/or the use of moving equipment.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 157:
# Text: When commanded, CSP_Mid.CBF shall use the packet counter defined in the DISH to CSP ICD to automatically detect and recover from lost packets without the need for any telescope calibration or other external action.
# Assigned Topic: 36_csp_cspmidcbf_ska1_sdp
#
#
# Test Document 158:
# Text: Product Markings shall withstand all environments and conditions to which the item will be subjected. Product Markings shall be waterproof and not detach or become unreadable with repeated handling.
# Assigned Topic: 46_markings_marking_labelled_packaging
#
#
# Test Document 159:
# Text: When commanded, CSP_Mid.CBF shall produce visibilities in support of VLBI with the following characteristics:
# 1. include all polarization products of all baselines including autocorrelations, for all receptors in the VLBI subarray;
# 2. have visibility channel response: maximum +/-0.1 dB amplitude and +/-0.01 radian phase passband (channel edge-to-edge) ripple; -3 dB +/-0.2 dB channel edge amplitude; monotonically decreasing amplitude from the channel edge to the adjacent channel far edge; at least -60 dB reject-band amplitude anywhere greater than the 1 channel width away from the channel edge;
# 3. have no detectable and uncorrectable amplitude variations as a function of time, after RFI flagging, and not due to RFI;
# 4. have at least 98% correlation efficiency, after RFI flagging, for residual unflagged RFI power <10% in the channel samples;
# 5. have no spurious spectral products in visibilities: (a) RFI- sourced: none above -60 dB relative to the (RFI) progenitor(s) for integration times up to 24 hrs; (b) non- RFI-sourced: none that don't integrate down as noise.
# 6. have integration times between 0.14 seconds +/-2% to 1.4 seconds +/-2%, configurable in steps within that range of at least as small as the minimum integration time or better;
# 7. have the same temporal cadence phase across Frequency Slices within the same Band (i.e. visibility timestamps are all aligned/"in-step" in time);
# 8. require no Time Centroid Index (TCI) calculation;
# 9. require no channel averaging or Channel Centroid Index (CCI) calculation;
# 10. linear channel-to-channel spacing across Frequency Slices within the same Band.
# Assigned Topic: 16_beamchannels_beamchannel_mhz_rfi
#
#
# Test Document 160:
# Text:  Each threading line shall have a pin end high speed threading station.
# Assigned Topic: 1_threading_line_dials_inspection
#
#
# Test Document 161:
# Text: Prior to starting fabrication the Supplier and the Supplierís approved Sub-Suppliers shall submit the following for Purchaser approval: Weld Specifications.
# Assigned Topic: 34_suppliers_supplier_contractual_fabrication
#
#
# Test Document 162:
# ...
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 242:
# Text:  Each pipe shall undergo end blast while rotating.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 243:
# Text: Pointing coordinate set
# The Pointing Coordinate Set shall consist of the following:
# a) Azimuth coordinate in the Dish's local reference system,
# b) Elevation coordinate in the Dish's local reference system,
# c) Desired future time by which the Dish is required to be pointing to the coordinates.
# Pointing coordinates will be corrected for refraction, and the time stamp will include time corrections specific to the DSH Dish.
# Assigned Topic: 3_dish_pointing_ranging_tracking
#
#
# Test Document 244:
# Text: Packaged LRU's and SRU's that require periodic maintenance during storage shall be
# packaged in red-coloured containers.
# Assigned Topic: 55_packaging_srus_packaged_carrying
#
#
# Test Document 245:
# Text:  Each station shall be able to accomodate casing diameter from four and one half inches to ten and three quarters inches.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 246:
# Text: Restrict operation of vehicles or equipment on the treated course for a
# minimum 7-day cure period after final finish rolling. Unless the contract specifies an asphalt
# curing seal, keep the surface lightly moistened during the curing period to prevent drying.
# Assigned Topic: 27_mixture_density_mixing_cement
#
#
# Test Document 247:
# Text: the operator panel for each module or system must report all machine stops and a reason why it occurred.
# Assigned Topic: 5_deactivation_hmis_hmi_timers
#
#
# Test Document 248:
# Text: Bobbin Weight: 600 pounds.
# Assigned Topic: 54_yarn_bobbins_bobbin_combs
#
#
# Test Document 249:
# Text: The steel shall be killed steel, with the primary melting process being open-hearth, basic-oxygen, or electric-furnace, possibly combined with separate degassing or refining. If secondary melting, using electroslag remelting or vacuum-arc remelting is subsequently employed, the heat shall be defined as all of the ingots remelted from a single primary heat
# Assigned Topic: 0_retests_testing_retest_test
#
#
# Test Document 250:
# Text: In all sampling modes, each data byte shall represent one sample for a polarization. The X and Y polarization samples shall be interleaved (even numbered samples for pol-X, odd numbered for pol-Y)
# In 4-bit sampling modes, each data byte shall represent two sub-bands of one-polarisation.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 251:
# Text: Component design and system performance shall be based on the following utilities and site conditions: Site Conditions Elevation: 836 Feet above Sea Level Atmospheric Pressure: 14.25 PSIA Ambient Temperature: -10∞F to 105∞F (-23.3∞C to 40.5∞C).
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 252:
# Text: The Creel height shall not exceed 17í-6î above the operating floor.
# Assigned Topic: 39_clearance_workbench_workstations_worker
#
#
# Test Document 253:
# Text:  The vrollers shall lower the pipe onto the transfer table to gravity roll towards the exit conveyor.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 254:
# Text: communication wiring will be run separately from ac inductive load wiring (> 65 volts).
# Assigned Topic: 10_wires_wire_coils_wiring
#
#
# Test Document 255:
# Text: When commanded, CSP_Mid.CBF shall flag real-time (pre- visibility integration and pre-beamforming summing) data streams at all available channel resolutions according to a pre-selected RFI Mask, in accordance with the CSP LMC to CSP Sub-elements ICD [SKA-TEL-CSP-0000019] and where the mask, for each stream to be flagged at each channel resolution, contains:
# 1. flagging ON/OFF,
# 2. non-RFI level establishment integration time,
# 3. non-RFI level setting (optional, overrides internal level determination),
# 4. RFI trigger algorithm (Power, Kurtosis),
# 5. RFI trigger detect integration time,
# 6. flagging trigger level and,
# 7. flagging dwell time or "Auto".
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 256:
# Text: CSP_Mid.CBF shall be compliant with the RoHS Directive 2011/65/EU (RoHS 2) or equivalent.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 257:
# Text: DSH shall be able to be in MAINTENANCE mode when in either FULL_POWER or in LOW_POWER state.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 258:
# Text: While tracking at rates up to 1°/s in Azimuth and 0.5°/s in Elevation, the Dish shall report pointing sensor values with sufficient resolution to permit the beam boresight direction to be estimated to within the tracking error of R.D.P.6, R.D.P.35 & R.D.P.36 (TBC).
# Assigned Topic: 3_dish_pointing_ranging_tracking
#
#
# Test Document 259:
# Text: When commanded, CSP_Mid.CBF shall apply a CSP_Mid.LMC-provided per-receptor, per-beam polarization calibration correction to each Frequency Slice independently, prior to VLBI beamforming.
# Assigned Topic: 16_beamchannels_beamchannel_mhz_rfi
#
#
# Test Document 260:
# Text: The ends of pipe sections at all joints and connections shall be washed or brushed clean and thoroughly wetted immediately prior to placing the mortar. Care should be taken to assure that all joints and connections are filled with mortar before joining to attain at least a 6 mm (0.25 in.) thick mortar joint and that excess mortar is wiped from the inside of the pipe. The external bands shall be complete around the circumference of the pipe and no less than 10 mm (0.4 in.) thick at the joint
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 261:
# Text:  The project inputs and outputs shall be defined to include customer specification and other information.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 262:
# Text: American Welding Society (AWS).
# Assigned Topic: 26_welded_tube_commissioning_equipment
#
#
# Test Document 263:
# Text: CSP_Mid.CBF power draw rate of change shall be less than 20% of the maximum power draw averaged over a one second interval (TBC) during startup and mode transitions in accordance with the latest approved version of the MID CSP to INFRA ICD.
# Assigned Topic: 17_cooling_cooled_thermal_cspmidcbf
#
#
# Test Document 264:
# Text: four pallet before and after all stations at 95% - 1.000% of the bottleneck cycle.
# Assigned Topic: 64_stations_station_pallet_project
#
#
# Test Document 265:
# Text:  Each threading line shall have a pin end threading inspection station.
# Assigned Topic: 1_threading_line_dials_inspection
#
#
# Test Document 266:
# Text: the fixture edges should be rounded to min 1.0 32 radius.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 267:
# Text:  Each box end high speed threading station shall be constructed of welded structural members.
# Assigned Topic: 22_welded_structural_frame_frames
#
#
# Test Document 268:
# Text: The Agency will base payment for quicklime upon a 90 percent available lime index calculated
# as percent calcium oxide (CaO) by weight.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 269:
# Text: All SKA1 Dish “off-the-shelf” equipment shall possess as a minimum the host country EMC marking.
# Assigned Topic: 33_ska1sysreq2180_ska1mid_sensitivity_polarization
#
#
# Test Document 270:
# Text: The Supplier shall furnish all equipment, controls, data, drawings, etc. defined in the Purchaserís documents and data including, but not limited to, the following major components: All rollers guides required to arrange fiber into final positions before entering the stretcher frame.
# Assigned Topic: 8_components_supplier_equipment_yarn
#
#
# Test Document 271:
# Text:  The project shall have acceptance.
# Assigned Topic: 25_planning_scheduled_meetings_schedule
#
#
# Test Document 272:
# Text: For each Pulsar Timing beam formed with CSP_Mid.CBF, the total aliased power in the total beamforming bandwidth of
# the beam, in the absence of RFI, shall be less than -60 dB.
# Assigned Topic: 13_mhz_pulsar_beamforming_frequency
#
#
# Test Document 273:
# Text: The total per-receptor Tracking Stability Error Circle diameter under Standard Operating Conditions, maintained while tracking a celestial target anywhere within the full performance pointing range over a time interval of 1000 seconds, shall be <= 18 arcsec.
# Assigned Topic: 19_precision_pointing_circle_perreceptor
#
#
# Test Document 274:
# Text: The interface between CSP_Mid.CBF and CSP_Mid.PST shall be compliant with the SKA1 CSP Correlator and Beamformer to Pulsar Timing Interface Control Document [SKA-TEL-CSP- 0000250].
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 275:
# Text: When commanded, CSP_Mid.CBF shall, for each subarray in each Frequency Slice Processor configured for Correlation, produce up to 14,000 to 16,384 visibility channels per-polarization for each of 4 polarizations, linearly spaced across at least the Frequency Slice or Zoom Window processed bandwidth.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 276:
# Text: Under precision and standard operating conditions, each SKA1_Mid dish shall achieve
# Dish sensitivity (averaged) of at least 6.31 m2/K in both polarization channels over SPF band 5b.
# Assigned Topic: 33_ska1sysreq2180_ska1mid_sensitivity_polarization
#
#
# Test Document 277:
# Text:  The operator shall press a button on the local pushbutton station and the pipe is transferred back out of the box end drift and threading protector station by vrollers until the proximity sensor is encountered and the pipe pin end is positioned for processing at the next station.
# Assigned Topic: 38_pipe_pushbutton_pushbuttons_button
#
#
# Test Document 278:
# Text: The 'mapChar' element maps from arbitrary character codes or arbitrary character code sequences, including Unicode, to Unicode.
# Assigned Topic: 59_languagepreferredcomponentdef_unicode_unicodeset_languagepreferredlist
#
#
# Test Document 279:
# Text: vertical toe clearance should be 4î.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 280:
# Text:  Each paddle lift shall be raised and lowered using a clevis mounted air cylinder with the available option of a ball screw actuator driven by an electric motor.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 281:
# Text: At a design point downstream from where there is opportunity for air entrainment and inadequate opportunity for escape of that air
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 282:
# Text: the distance from the front of part bins to the front edge of the workstation will not exceed 1.08 inches.
# Assigned Topic: 39_clearance_workbench_workstations_worker
#
#
# Test Document 283:
# Text: There shall be space at the Gregorian focus of SKA1 dishes for five single pixel feeds (SPF).
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 284:
# Text: When commanded and processing data from Band 5a, CSP_Mid.CBF shall accept two streams (5a1 and 5a2) of dual polarization digitized data from each SKA1_Mid receptor. For each stream:
# 1. the sample rate is 5.94+k*3/2*delta_f/1e9 Gsamples/sec.
# 2. the bandwidth of the band of interest is 2.5 GHz
# 3. the sky RF center frequency may be TM-defined tuned anywhere between f_c_rf=5.85 and f_c_rf=7.25 GHz
# 4. the center frequency of the band of interest in the digitized signal is f_c_boi=1.485-k*9/8*delta_f/1e9 + f_shift GHz
# 5. has the same frequency sense as RF and
# 6. has net downconversion frequency of f_c_rf_c_boi=f_c_rf- f_c_boi
# Where: k=positive integer defined for each receptor by CSP_Mid.LMC, delta_f=1800 Hz, f_shift is CSP_Mid.LMC-defined anywhere in the range of at least +/-1/2 Frequency Slice processed bandwidth with at least 0.01 MHz tuning resolution, and k*3/2*delta_f does not exceed 4 MHz.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 285:
# Text: CSP_Mid.CBF equipment connected to the CPF electrical network shall be compliant with the IEC 61000-4-5 standard or equivalent for Surge immunity under standard test conditions and setups in accordance with the latest approved version of the MID CSP to INFRA ICD.
# Assigned Topic: 15_iec_cspmidcbf_csp_cpf
#
#
# Test Document 286:
# Text: The SKA1-Mid Dish shall have an Inherent Availability (Ai) of = 99.90%.
# Assigned Topic: 41_ska1_ska1mid_rms_dish
#
#
# Test Document 287:
# Text: This request is sent from the Origin Cloud to the Target Cloud in order to obtain information on all the Devices that are registered for the user that are in scope as defined by the Bearer Token on the Target Cloud.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 288:
# Text: The total per-receptor RMS Relative Pointing Error under Standard Operating Conditions, between any two points within the full performance pointing range that are separated by up to 10° great circle distance and measured within a time interval of 100 seconds, shall be <= 2.6 arcsec RMS.
# Assigned Topic: 19_precision_pointing_circle_perreceptor
#
#
# Test Document 289:
# Text: Latency from the time a measurement crosses an alarm set-point until the time it is signalled to TM shall be no more than 5 seconds.
# {not compliant to L1}
# Assigned Topic: 3_dish_pointing_ranging_tracking
#
#
# Test Document 290:
# Text: CSP_Mid.CBF shall provide hardware and communication access to any authenticated user.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 291:
# Text:  If additional support is required then AEC shall provide this service at standard service rates.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 292:
# Text:  Each box end end blast station shall have powered pipe radial rollers.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 293:
# Text:  Each station base shall be constructed of heavy wall structural tubing with telescoped legs for onsite precise leveling during installation.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 294:
# Text:  The operator shall have a local operator pushbutton station to transfer pipe in and indicate completion for pipe transfer out of the bucker station.
# Assigned Topic: 38_pipe_pushbutton_pushbuttons_button
#
#
# Test Document 295:
# Text: This measurement shall be made in test cavity according to Drawing 162-JAN. With the cavity calibrator in position, the cavity shall be tuned to resonance and the relative transmitted power level noted. With the tube inserted, the cavity shall then be tuned to resonance and the transmitted power noted. The dB loss in transmitted power due to the insertion of the tube shall not be more than the specified amount.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 296:
# Text: all test related equipment is required to have isolated dc power supplies when used for measuring or testing applications.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 297:
# Text: CSP_Mid.CBF shall monitor its operational state at all times and report the information upon request.
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 298:
# Text: A vendor may extend the list of OAuth2.0 access token scopes beyond those listed in Table 2. They are extended by adding additional vendor-specific information before the * in the OAuth2.0 access token scope name (e.g. "r:xyz:*"). How these extensions work is outside the scope of the OCF but they may be present in the OAuth2.0 access token request. Note that if the user gives consent to the Origin Cloud to "w:*", consent applies also to any derived OAuth2.0 access token scopes (e.g. "w:xyz:*").
# Assigned Topic: -1_rf_ghz_mhz_frequency
#
#
# Test Document 299:
# Text: When agreed upon by the purchaser and producer, the maximum decarburization at any as-cast surface after heat treatment may be stipulated in writing, as measured by visual depletion of combined carbon after polishing, etching in nital, and viewing at 100×
# Assigned Topic: 0_retests_testing_retest_test
#
#
# Test Document 300:
# Text: While the CSP_Mid.CBF Administrative Mode is set to ONLINE or MAINTENANCE, CSP_Mid.CBF shall perform diagnostic tests to detect and isolate LRU and sub-element faults.
# Assigned Topic: 12_cspmidcbf_cspmidlmc_faults_maintenance
#
#
# Test Document 301:
# Text: all ac motors above 25hp shall be wired with continuous conductors from the control cabinet no intermediate connections will be permitted.
# Assigned Topic: 32_wiring_wires_relays_wire
